# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from xgboost import XGBClassifier
from itertools import product
from collections import defaultdict
import shap
from scipy.signal import correlate
from copy import deepcopy

# %%
from sklearn.metrics import roc_auc_score

# %%
from sklearn.model_selection import StratifiedShuffleSplit
kf = StratifiedShuffleSplit(n_splits=5)

# %%
series = pd.read_csv('train.csv')
series.head()
# Out:
#    sequence  subject  step  sensor_00  sensor_01  sensor_02  sensor_03  \
# 0         0       47     0  -0.196291   0.112395        1.0   0.329204
# 1         0       47     1  -0.447450   0.134454        1.0  -0.658407
# 2         0       47     2   0.326893  -0.694328        1.0   0.330088
# 3         0       47     3   0.523184   0.751050        1.0   0.976991
# 4         0       47     4   0.272025   1.074580        1.0  -0.136283
#
#    sensor_04  sensor_05  sensor_06  sensor_07  sensor_08  sensor_09  \
# 0  -1.004660  -0.131638  -0.127505   0.368702       -0.1  -0.963873
# 1   0.162495   0.340314  -0.209472  -0.867176        0.2  -0.301301
# 2   0.473678   1.280479  -0.094718   0.535878        1.4   1.002168
# 3  -0.563287  -0.720269   0.793260   0.951145       -0.3  -0.995665
# 4   0.398579   0.044877   0.560109  -0.541985       -0.9   1.055636
#
#    sensor_10  sensor_11  sensor_12
# 0  -0.985069   0.531893   4.751492
# 1   0.082733  -0.231481   0.454390
# 2   0.449221  -0.586420  -4.736147
# 3  -0.434290   1.344650   0.429241
# 4   0.812631   0.123457  -0.223359

# %%
labels = pd.read_csv('train_labels.csv', index_col=['sequence'])
labels.head()
# Out:
#           state
# sequence
# 0             0
# 1             1
# 2             1
# 3             1
# 4             1

# %% [markdown]
# some ideas from https://www.kaggle.com/code/dmitryuarov/tps-sensors-2xlstm-xgb-auc-0-976#XGB

# %% [markdown]
# quantile needs a decoration: https://stackoverflow.com/questions/17578115/pass-percentiles-to-pandas-agg-function

# %%
def quantile(q):
    def quantile_(x):
        return np.quantile(x,q)
    quantile_.__name__ = f"quantile_{str(q)}"
    return quantile_

# %%
def prep(df):
    result = pd.DataFrame()
    result['sequence'] = df['sequence'].unique()
    result = result.merge(df[['sequence','subject']], how='left',on='sequence')
    
    for sensor in df.columns[3:]:
        print(f"doing {sensor}")
        aggs = df.groupby('sequence').agg({sensor:['mean','std','median','mad',
                                                      'min','max','sum','skew',
                                                   quantile(0.1), quantile(0.9)]})
        aggs.columns = aggs.columns.map('_'.join)
        result = result.merge(aggs.reset_index(),how='left',on='sequence')
        print(result.columns)

    for sensor in df.columns[3:]:
        print(f"doing {sensor}")
        aggs = df.groupby('subject').agg({sensor:['mean','std','median','mad',
                                                      'min','max','sum','skew',
                                                   quantile(0.1), quantile(0.9)]})
        aggs.columns = aggs.columns.map('_subject_'.join)
        result = result.merge(aggs.reset_index(),how='left',on='subject')
        print(result.columns)
    
    
    result = result.drop_duplicates()
    result.index = np.arange(len(result))
    return result

# %%
train = prep(series)
# Out:
# doing sensor_00
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew', 'sensor_00_quantile_0.1',
#        'sensor_00_quantile_0.9'],
#       dtype='object')
# doing sensor_01
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew', 'sensor_00_quantile_0.1',
#        'sensor_00_quantile_0.9', 'sensor_01_mean', 'sensor_01_std',
#        'sensor_01_median', 'sensor_01_mad', 'sensor_01_min', 'sensor_01_max',
#        'sensor_01_sum', 'sensor_01_skew', 'sensor_01_quantile_0.1',
#        'sensor_01_quantile_0.9'],
#       dtype='object')
# doing sensor_02
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew', 'sensor_00_quantile_0.1',
#        'sensor_00_quantile_0.9', 'sensor_01_mean', 'sensor_01_std',
#        'sensor_01_median', 'sensor_01_mad', 'sensor_01_min', 'sensor_01_max',
#        'sensor_01_sum', 'sensor_01_skew', 'sensor_01_quantile_0.1',
#        'sensor_01_quantile_0.9', 'sensor_02_mean', 'sensor_02_std',
#        'sensor_02_median', 'sensor_02_mad', 'sensor_02_min', 'sensor_02_max',
#        'sensor_02_sum', 'sensor_02_skew', 'sensor_02_quantile_0.1',
#        'sensor_02_quantile_0.9'],
#       dtype='object')
# doing sensor_03
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew', 'sensor_00_quantile_0.1',
#        'sensor_00_quantile_0.9', 'sensor_01_mean', 'sensor_01_std',
#        'sensor_01_median', 'sensor_01_mad', 'sensor_01_min', 'sensor_01_max',
#        'sensor_01_sum', 'sensor_01_skew', 'sensor_01_quantile_0.1',
#        'sensor_01_quantile_0.9', 'sensor_02_mean', 'sensor_02_std',
#        'sensor_02_median', 'sensor_02_mad', 'sensor_02_min', 'sensor_02_max',
#        'sensor_02_sum', 'sensor_02_skew', 'sensor_02_quantile_0.1',
#        'sensor_02_quantile_0.9', 'sensor_03_mean', 'sensor_03_std',
#        'sensor_03_median', 'sensor_03_mad', 'sensor_03_min', 'sensor_03_max',
#        'sensor_03_sum', 'sensor_03_skew', 'sensor_03_quantile_0.1',
#        'sensor_03_quantile_0.9'],
#       dtype='object')
# doing sensor_04
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew', 'sensor_00_quantile_0.1',
#        'sensor_00_quantile_0.9', 'sensor_01_mean', 'sensor_01_std',
#        'sensor_01_median', 'sensor_01_mad', 'sensor_01_min', 'sensor_01_max',
#        'sensor_01_sum', 'sensor_01_skew', 'sensor_01_quantile_0.1',
#        'sensor_01_quantile_0.9', 'sensor_02_mean', 'sensor_02_std',
#        'sensor_02_median', 'sensor_02_mad', 'sensor_02_min', 'sensor_02_max',
#        'sensor_02_sum', 'sensor_02_skew', 'sensor_02_quantile_0.1',
#        'sensor_02_quantile_0.9', 'sensor_03_mean', 'sensor_03_std',
#        'sensor_03_median', 'sensor_03_mad', 'sensor_03_min', 'sensor_03_max',
#        'sensor_03_sum', 'sensor_03_skew', 'sensor_03_quantile_0.1',
#        'sensor_03_quantile_0.9', 'sensor_04_mean', 'sensor_04_std',
#        'sensor_04_median', 'sensor_04_mad', 'sensor_04_min', 'sensor_04_max',
#        'sensor_04_sum', 'sensor_04_skew', 'sensor_04_quantile_0.1',
#        'sensor_04_quantile_0.9'],
#       dtype='object')
# doing sensor_05
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew', 'sensor_00_quantile_0.1',
#        'sensor_00_quantile_0.9', 'sensor_01_mean', 'sensor_01_std',
#        'sensor_01_median', 'sensor_01_mad', 'sensor_01_min', 'sensor_01_max',
#        'sensor_01_sum', 'sensor_01_skew', 'sensor_01_quantile_0.1',
#        'sensor_01_quantile_0.9', 'sensor_02_mean', 'sensor_02_std',
#        'sensor_02_median', 'sensor_02_mad', 'sensor_02_min', 'sensor_02_max',
#        'sensor_02_sum', 'sensor_02_skew', 'sensor_02_quantile_0.1',
#        'sensor_02_quantile_0.9', 'sensor_03_mean', 'sensor_03_std',
#        'sensor_03_median', 'sensor_03_mad', 'sensor_03_min', 'sensor_03_max',
#        'sensor_03_sum', 'sensor_03_skew', 'sensor_03_quantile_0.1',
#        'sensor_03_quantile_0.9', 'sensor_04_mean', 'sensor_04_std',
#        'sensor_04_median', 'sensor_04_mad', 'sensor_04_min', 'sensor_04_max',
#        'sensor_04_sum', 'sensor_04_skew', 'sensor_04_quantile_0.1',
#        'sensor_04_quantile_0.9', 'sensor_05_mean', 'sensor_05_std',
#        'sensor_05_median', 'sensor_05_mad', 'sensor_05_min', 'sensor_05_max',
#        'sensor_05_sum', 'sensor_05_skew', 'sensor_05_quantile_0.1',
#        'sensor_05_quantile_0.9'],
#       dtype='object')
# doing sensor_06
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew', 'sensor_00_quantile_0.1',
#        'sensor_00_quantile_0.9', 'sensor_01_mean', 'sensor_01_std',
#        'sensor_01_median', 'sensor_01_mad', 'sensor_01_min', 'sensor_01_max',
#        'sensor_01_sum', 'sensor_01_skew', 'sensor_01_quantile_0.1',
#        'sensor_01_quantile_0.9', 'sensor_02_mean', 'sensor_02_std',
#        'sensor_02_median', 'sensor_02_mad', 'sensor_02_min', 'sensor_02_max',
#        'sensor_02_sum', 'sensor_02_skew', 'sensor_02_quantile_0.1',
#        'sensor_02_quantile_0.9', 'sensor_03_mean', 'sensor_03_std',
#        'sensor_03_median', 'sensor_03_mad', 'sensor_03_min', 'sensor_03_max',
#        'sensor_03_sum', 'sensor_03_skew', 'sensor_03_quantile_0.1',
#        'sensor_03_quantile_0.9', 'sensor_04_mean', 'sensor_04_std',
#        'sensor_04_median', 'sensor_04_mad', 'sensor_04_min', 'sensor_04_max',
#        'sensor_04_sum', 'sensor_04_skew', 'sensor_04_quantile_0.1',
#        'sensor_04_quantile_0.9', 'sensor_05_mean', 'sensor_05_std',
#        'sensor_05_median', 'sensor_05_mad', 'sensor_05_min', 'sensor_05_max',
#        'sensor_05_sum', 'sensor_05_skew', 'sensor_05_quantile_0.1',
#        'sensor_05_quantile_0.9', 'sensor_06_mean', 'sensor_06_std',
#        'sensor_06_median', 'sensor_06_mad', 'sensor_06_min', 'sensor_06_max',
#        'sensor_06_sum', 'sensor_06_skew', 'sensor_06_quantile_0.1',
#        'sensor_06_quantile_0.9'],
#       dtype='object')
# doing sensor_07
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew', 'sensor_00_quantile_0.1',
#        'sensor_00_quantile_0.9', 'sensor_01_mean', 'sensor_01_std',
#        'sensor_01_median', 'sensor_01_mad', 'sensor_01_min', 'sensor_01_max',
#        'sensor_01_sum', 'sensor_01_skew', 'sensor_01_quantile_0.1',
#        'sensor_01_quantile_0.9', 'sensor_02_mean', 'sensor_02_std',
#        'sensor_02_median', 'sensor_02_mad', 'sensor_02_min', 'sensor_02_max',
#        'sensor_02_sum', 'sensor_02_skew', 'sensor_02_quantile_0.1',
#        'sensor_02_quantile_0.9', 'sensor_03_mean', 'sensor_03_std',
#        'sensor_03_median', 'sensor_03_mad', 'sensor_03_min', 'sensor_03_max',
#        'sensor_03_sum', 'sensor_03_skew', 'sensor_03_quantile_0.1',
#        'sensor_03_quantile_0.9', 'sensor_04_mean', 'sensor_04_std',
#        'sensor_04_median', 'sensor_04_mad', 'sensor_04_min', 'sensor_04_max',
#        'sensor_04_sum', 'sensor_04_skew', 'sensor_04_quantile_0.1',
#        'sensor_04_quantile_0.9', 'sensor_05_mean', 'sensor_05_std',
#        'sensor_05_median', 'sensor_05_mad', 'sensor_05_min', 'sensor_05_max',
#        'sensor_05_sum', 'sensor_05_skew', 'sensor_05_quantile_0.1',
#        'sensor_05_quantile_0.9', 'sensor_06_mean', 'sensor_06_std',
#        'sensor_06_median', 'sensor_06_mad', 'sensor_06_min', 'sensor_06_max',
#        'sensor_06_sum', 'sensor_06_skew', 'sensor_06_quantile_0.1',
#        'sensor_06_quantile_0.9', 'sensor_07_mean', 'sensor_07_std',
#        'sensor_07_median', 'sensor_07_mad', 'sensor_07_min', 'sensor_07_max',
#        'sensor_07_sum', 'sensor_07_skew', 'sensor_07_quantile_0.1',
#        'sensor_07_quantile_0.9'],
#       dtype='object')
# doing sensor_08
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew', 'sensor_00_quantile_0.1',
#        'sensor_00_quantile_0.9', 'sensor_01_mean', 'sensor_01_std',
#        'sensor_01_median', 'sensor_01_mad', 'sensor_01_min', 'sensor_01_max',
#        'sensor_01_sum', 'sensor_01_skew', 'sensor_01_quantile_0.1',
#        'sensor_01_quantile_0.9', 'sensor_02_mean', 'sensor_02_std',
#        'sensor_02_median', 'sensor_02_mad', 'sensor_02_min', 'sensor_02_max',
#        'sensor_02_sum', 'sensor_02_skew', 'sensor_02_quantile_0.1',
#        'sensor_02_quantile_0.9', 'sensor_03_mean', 'sensor_03_std',
#        'sensor_03_median', 'sensor_03_mad', 'sensor_03_min', 'sensor_03_max',
#        'sensor_03_sum', 'sensor_03_skew', 'sensor_03_quantile_0.1',
#        'sensor_03_quantile_0.9', 'sensor_04_mean', 'sensor_04_std',
#        'sensor_04_median', 'sensor_04_mad', 'sensor_04_min', 'sensor_04_max',
#        'sensor_04_sum', 'sensor_04_skew', 'sensor_04_quantile_0.1',
#        'sensor_04_quantile_0.9', 'sensor_05_mean', 'sensor_05_std',
#        'sensor_05_median', 'sensor_05_mad', 'sensor_05_min', 'sensor_05_max',
#        'sensor_05_sum', 'sensor_05_skew', 'sensor_05_quantile_0.1',
#        'sensor_05_quantile_0.9', 'sensor_06_mean', 'sensor_06_std',
#        'sensor_06_median', 'sensor_06_mad', 'sensor_06_min', 'sensor_06_max',
#        'sensor_06_sum', 'sensor_06_skew', 'sensor_06_quantile_0.1',
#        'sensor_06_quantile_0.9', 'sensor_07_mean', 'sensor_07_std',
#        'sensor_07_median', 'sensor_07_mad', 'sensor_07_min', 'sensor_07_max',
#        'sensor_07_sum', 'sensor_07_skew', 'sensor_07_quantile_0.1',
#        'sensor_07_quantile_0.9', 'sensor_08_mean', 'sensor_08_std',
#        'sensor_08_median', 'sensor_08_mad', 'sensor_08_min', 'sensor_08_max',
#        'sensor_08_sum', 'sensor_08_skew', 'sensor_08_quantile_0.1',
#        'sensor_08_quantile_0.9'],
#       dtype='object')
# doing sensor_09
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew',
#        ...
#        'sensor_09_mean', 'sensor_09_std', 'sensor_09_median', 'sensor_09_mad',
#        'sensor_09_min', 'sensor_09_max', 'sensor_09_sum', 'sensor_09_skew',
#        'sensor_09_quantile_0.1', 'sensor_09_quantile_0.9'],
#       dtype='object', length=102)
# doing sensor_10
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew',
#        ...
#        'sensor_10_mean', 'sensor_10_std', 'sensor_10_median', 'sensor_10_mad',
#        'sensor_10_min', 'sensor_10_max', 'sensor_10_sum', 'sensor_10_skew',
#        'sensor_10_quantile_0.1', 'sensor_10_quantile_0.9'],
#       dtype='object', length=112)
# doing sensor_11
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew',
#        ...
#        'sensor_11_mean', 'sensor_11_std', 'sensor_11_median', 'sensor_11_mad',
#        'sensor_11_min', 'sensor_11_max', 'sensor_11_sum', 'sensor_11_skew',
#        'sensor_11_quantile_0.1', 'sensor_11_quantile_0.9'],
#       dtype='object', length=122)
# doing sensor_12
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew',
#        ...
#        'sensor_12_mean', 'sensor_12_std', 'sensor_12_median', 'sensor_12_mad',
#        'sensor_12_min', 'sensor_12_max', 'sensor_12_sum', 'sensor_12_skew',
#        'sensor_12_quantile_0.1', 'sensor_12_quantile_0.9'],
#       dtype='object', length=132)
# doing sensor_00
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew',
#        ...
#        'sensor_00_subject_mean', 'sensor_00_subject_std',
#        'sensor_00_subject_median', 'sensor_00_subject_mad',
#        'sensor_00_subject_min', 'sensor_00_subject_max',
#        'sensor_00_subject_sum', 'sensor_00_subject_skew',
#        'sensor_00_subject_quantile_0.1', 'sensor_00_subject_quantile_0.9'],
#       dtype='object', length=142)
# doing sensor_01
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew',
#        ...
#        'sensor_01_subject_mean', 'sensor_01_subject_std',
#        'sensor_01_subject_median', 'sensor_01_subject_mad',
#        'sensor_01_subject_min', 'sensor_01_subject_max',
#        'sensor_01_subject_sum', 'sensor_01_subject_skew',
#        'sensor_01_subject_quantile_0.1', 'sensor_01_subject_quantile_0.9'],
#       dtype='object', length=152)
# doing sensor_02
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew',
#        ...
#        'sensor_02_subject_mean', 'sensor_02_subject_std',
#        'sensor_02_subject_median', 'sensor_02_subject_mad',
#        'sensor_02_subject_min', 'sensor_02_subject_max',
#        'sensor_02_subject_sum', 'sensor_02_subject_skew',
#        'sensor_02_subject_quantile_0.1', 'sensor_02_subject_quantile_0.9'],
#       dtype='object', length=162)
# doing sensor_03
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew',
#        ...
#        'sensor_03_subject_mean', 'sensor_03_subject_std',
#        'sensor_03_subject_median', 'sensor_03_subject_mad',
#        'sensor_03_subject_min', 'sensor_03_subject_max',
#        'sensor_03_subject_sum', 'sensor_03_subject_skew',
#        'sensor_03_subject_quantile_0.1', 'sensor_03_subject_quantile_0.9'],
#       dtype='object', length=172)
# doing sensor_04
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew',
#        ...
#        'sensor_04_subject_mean', 'sensor_04_subject_std',
#        'sensor_04_subject_median', 'sensor_04_subject_mad',
#        'sensor_04_subject_min', 'sensor_04_subject_max',
#        'sensor_04_subject_sum', 'sensor_04_subject_skew',
#        'sensor_04_subject_quantile_0.1', 'sensor_04_subject_quantile_0.9'],
#       dtype='object', length=182)
# doing sensor_05
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew',
#        ...
#        'sensor_05_subject_mean', 'sensor_05_subject_std',
#        'sensor_05_subject_median', 'sensor_05_subject_mad',
#        'sensor_05_subject_min', 'sensor_05_subject_max',
#        'sensor_05_subject_sum', 'sensor_05_subject_skew',
#        'sensor_05_subject_quantile_0.1', 'sensor_05_subject_quantile_0.9'],
#       dtype='object', length=192)
# doing sensor_06
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew',
#        ...
#        'sensor_06_subject_mean', 'sensor_06_subject_std',
#        'sensor_06_subject_median', 'sensor_06_subject_mad',
#        'sensor_06_subject_min', 'sensor_06_subject_max',
#        'sensor_06_subject_sum', 'sensor_06_subject_skew',
#        'sensor_06_subject_quantile_0.1', 'sensor_06_subject_quantile_0.9'],
#       dtype='object', length=202)
# doing sensor_07
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew',
#        ...
#        'sensor_07_subject_mean', 'sensor_07_subject_std',
#        'sensor_07_subject_median', 'sensor_07_subject_mad',
#        'sensor_07_subject_min', 'sensor_07_subject_max',
#        'sensor_07_subject_sum', 'sensor_07_subject_skew',
#        'sensor_07_subject_quantile_0.1', 'sensor_07_subject_quantile_0.9'],
#       dtype='object', length=212)
# doing sensor_08
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew',
#        ...
#        'sensor_08_subject_mean', 'sensor_08_subject_std',
#        'sensor_08_subject_median', 'sensor_08_subject_mad',
#        'sensor_08_subject_min', 'sensor_08_subject_max',
#        'sensor_08_subject_sum', 'sensor_08_subject_skew',
#        'sensor_08_subject_quantile_0.1', 'sensor_08_subject_quantile_0.9'],
#       dtype='object', length=222)
# doing sensor_09
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew',
#        ...
#        'sensor_09_subject_mean', 'sensor_09_subject_std',
#        'sensor_09_subject_median', 'sensor_09_subject_mad',
#        'sensor_09_subject_min', 'sensor_09_subject_max',
#        'sensor_09_subject_sum', 'sensor_09_subject_skew',
#        'sensor_09_subject_quantile_0.1', 'sensor_09_subject_quantile_0.9'],
#       dtype='object', length=232)
# doing sensor_10
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew',
#        ...
#        'sensor_10_subject_mean', 'sensor_10_subject_std',
#        'sensor_10_subject_median', 'sensor_10_subject_mad',
#        'sensor_10_subject_min', 'sensor_10_subject_max',
#        'sensor_10_subject_sum', 'sensor_10_subject_skew',
#        'sensor_10_subject_quantile_0.1', 'sensor_10_subject_quantile_0.9'],
#       dtype='object', length=242)
# doing sensor_11
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew',
#        ...
#        'sensor_11_subject_mean', 'sensor_11_subject_std',
#        'sensor_11_subject_median', 'sensor_11_subject_mad',
#        'sensor_11_subject_min', 'sensor_11_subject_max',
#        'sensor_11_subject_sum', 'sensor_11_subject_skew',
#        'sensor_11_subject_quantile_0.1', 'sensor_11_subject_quantile_0.9'],
#       dtype='object', length=252)
# doing sensor_12
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew',
#        ...
#        'sensor_12_subject_mean', 'sensor_12_subject_std',
#        'sensor_12_subject_median', 'sensor_12_subject_mad',
#        'sensor_12_subject_min', 'sensor_12_subject_max',
#        'sensor_12_subject_sum', 'sensor_12_subject_skew',
#        'sensor_12_subject_quantile_0.1', 'sensor_12_subject_quantile_0.9'],
#       dtype='object', length=262)

# %%
train.head()
# Out:
#    sequence  subject  sensor_00_mean  sensor_00_std  sensor_00_median  \
# 0         0       47        0.041744       1.431660         -0.148764
# 1         1       66       -0.069294       1.593907         -0.031298
# 2         2       66       -0.001546       1.147526          0.058733
# 3         3      542        0.029869       1.769705         -0.119784
# 4         4      437        0.059132       2.014779          0.005410
#
#    sensor_00_mad  sensor_00_min  sensor_00_max  sensor_00_sum  sensor_00_skew  \
# 0       0.829612      -5.634467       7.534003       2.504637        1.488052
# 1       0.964271      -6.657651       5.870943      -4.157651       -0.683454
# 2       0.855307      -2.797527       3.402628      -0.092736        0.122688
# 3       1.379164      -3.643740       4.856260       1.792117        0.306005
# 4       1.495183      -5.331530       5.455951       3.547913       -0.216130
#
#    ...  sensor_12_subject_mean  sensor_12_subject_std  \
# 0  ...               -0.078774              20.293662
# 1  ...               -0.707871              46.380511
# 2  ...               -0.707871              46.380511
# 3  ...                0.001263               0.533071
# 4  ...                0.000280               0.318285
#
#    sensor_12_subject_median  sensor_12_subject_mad  sensor_12_subject_min  \
# 0                 -0.254476              12.579934            -312.621910
# 1                 -0.006181              21.210487            -317.453112
# 2                 -0.006181              21.210487            -317.453112
# 3                 -0.012788               0.349181              -3.136829
# 4                  0.003410               0.216635              -2.805200
#
#    sensor_12_subject_max  sensor_12_subject_sum  sensor_12_subject_skew  \
# 0             213.832481            -491.551151               -0.709353
# 1             268.698210           -1189.222933               -0.249052
# 2             268.698210           -1189.222933               -0.249052
# 3               3.487639               6.289855                0.321107
# 4               2.629156               3.347826               -0.224039
#
#    sensor_12_subject_quantile_0.1  sensor_12_subject_quantile_0.9
# 0                      -18.520588                       19.573359
# 1                      -41.808824                       36.950000
# 2                      -41.808824                       36.950000
# 3                       -0.538107                        0.558227
# 4                       -0.394288                        0.387937
#
# [5 rows x 262 columns]

# %%
train['label'] = labels['state']

# %%
series.columns[3:]
# Out:
# Index(['sensor_00', 'sensor_01', 'sensor_02', 'sensor_03', 'sensor_04',
#        'sensor_05', 'sensor_06', 'sensor_07', 'sensor_08', 'sensor_09',
#        'sensor_10', 'sensor_11', 'sensor_12'],
#       dtype='object')

# %%
template = pd.read_csv('template_sensor_04.csv').values

# %%
plt.plot(template.T);

# %%
tmp = series[series['sequence']==0]['sensor_04'].values
tmp
# Out:
# array([-1.00465964,  0.16249532,  0.47367847, -0.563287  ,  0.39857873,
#         0.46973569, -0.59696422, -0.05998317, -0.07171799, -0.75522067,
#         0.38657898,  0.9718863 , -0.29534971, -0.34096434,  0.67935731,
#         0.16001745, -0.70331006,  0.26573993,  0.29422765, -0.86120808,
#        -0.04739122,  0.64357624, -0.32019075, -0.28190064,  0.56617005,
#        -0.01472697, -0.77937601,  0.42042763,  0.00615572,  0.36945206,
#         0.4990182 , -0.79483543, -0.47579791,  0.63547251, -0.07489714,
#        -0.59948884,  0.61622616,  0.59515646, -0.61611707, -0.83036716,
#         0.5812087 ,  0.48253023, -0.62143124,  0.3047625 ,  0.50612455,
#        -0.83487096, -0.03218115,  0.71778768, -0.40175789, -0.80529236,
#         0.66142002,  0.65317604, -0.95027116,  0.00335058,  0.96074367,
#        -0.58000873, -1.60439783,  0.18320658,  0.14497881, -1.18172609])

# %%
tmp -= np.mean(tmp)
power = np.sqrt(np.sum(np.power(tmp,2)))
tmp /= power

# %%
template.shape, tmp.shape
# Out:
# ((15, 1), (60,))

# %%
correlate(template.reshape(-1), tmp, mode='valid')
# Out:
# array([-0.00863899,  0.13412693,  0.20537601, -0.04505788, -0.10959376,
#         0.07459723,  0.00534459, -0.12526843,  0.01637076,  0.07617632,
#        -0.01962284,  0.05256459,  0.12451999, -0.07337157, -0.20229659,
#         0.00725265,  0.12749248, -0.00096276,  0.02502201,  0.08944679,
#        -0.07755411, -0.16185793, -0.02973512,  0.07215983,  0.13130308,
#         0.07530962, -0.07688385, -0.06187012,  0.01717632, -0.04030151,
#        -0.028887  ,  0.10991204,  0.03497222, -0.11394318, -0.02143803,
#         0.02965154, -0.07983176, -0.01844837,  0.10429966, -0.00025044,
#        -0.02626442,  0.15569956,  0.12526688, -0.05235461, -0.08563541,
#        -0.13424569])

# %%
def prep_corr(df, dfout):
    sensors = df.columns[3:]
    for sensor in sensors:
        X = df[sensor].values.reshape(-1,60).copy()
        mean = np.mean(X, axis=1)[:, np.newaxis]
        X = X - mean
        power = np.sum(np.power(X, 2), axis=1)
        power[power==0] = 1
        power = np.sqrt(power)[:,np.newaxis]
        X = X / power
        
        template = pd.read_csv('template_' + sensor + '.csv').values.reshape(1,-1)
        dfout[sensor+'_corr'] = np.max(correlate(template, X, mode='valid')[::-1], axis=1)

# %%
prep_corr(series, train)

# %%
train
# Out:
#        sequence  subject  sensor_00_mean  sensor_00_std  sensor_00_median  \
# 0             0       47        0.041744       1.431660         -0.148764
# 1             1       66       -0.069294       1.593907         -0.031298
# 2             2       66       -0.001546       1.147526          0.058733
# 3             3      542        0.029869       1.769705         -0.119784
# 4             4      437        0.059132       2.014779          0.005410
# ...         ...      ...             ...            ...               ...
# 25963     25963      558        0.100773       1.547826          0.193586
# 25964     25964      297        0.017182       1.054727          0.051777
# 25965     25965      129       -0.006466       1.227428         -0.039413
# 25966     25966      170       -0.040417       0.885836         -0.051391
# 25967     25967      327       -0.011850       0.729595          0.069938
#
#        sensor_00_mad  sensor_00_min  sensor_00_max  sensor_00_sum  \
# 0           0.829612      -5.634467       7.534003       2.504637
# 1           0.964271      -6.657651       5.870943      -4.157651
# 2           0.855307      -2.797527       3.402628      -0.092736
# 3           1.379164      -3.643740       4.856260       1.792117
# 4           1.495183      -5.331530       5.455951       3.547913
# ...              ...            ...            ...            ...
# 25963       1.166378      -3.738022       3.974498       6.046368
# 25964       0.646433      -5.220247       2.927357       1.030912
# 25965       0.952644      -3.422720       2.818393      -0.387944
# 25966       0.679951      -2.069552       1.710974      -2.425039
# 25967       0.563919      -2.343895       2.016229      -0.710974
#
#        sensor_00_skew  ...  sensor_03_corr  sensor_04_corr  sensor_05_corr  \
# 0            1.488052  ...        0.234139        0.205376        0.311452
# 1           -0.683454  ...        0.477971        0.441894        0.320698
# 2            0.122688  ...        0.402786        0.530354        0.484730
# 3            0.306005  ...        0.465588        0.242902        0.450173
# 4           -0.216130  ...        0.282975        0.146067        0.267310
# ...               ...  ...             ...             ...             ...
# 25963        0.069687  ...        0.350901        0.151991        0.578738
# 25964       -1.690229  ...        0.282149        0.157277        0.285754
# 25965       -0.142272  ...        0.229817        0.283425        0.327730
# 25966       -0.259944  ...        0.553525        0.365728        0.262400
# 25967       -0.180554  ...        0.330215        0.196594        0.377231
#
#        sensor_06_corr  sensor_07_corr  sensor_08_corr  sensor_09_corr  \
# 0            0.305719        0.198836        0.442239        0.283562
# 1            0.383905        0.538582        0.367945        0.573946
# 2            0.419941        0.320479        0.409183        0.365350
# 3            0.307201        0.517353        0.418139        0.484548
# 4            0.404221        0.257423        0.344855        0.411843
# ...               ...             ...             ...             ...
# 25963        0.149248        0.536950        0.356715        0.237311
# 25964        0.286795        0.350339        0.323952        0.174574
# 25965        0.375871        0.293960        0.450384        0.200095
# 25966        0.462162        0.445991        0.578244        0.244693
# 25967        0.339719        0.403829        0.389365        0.162789
#
#        sensor_10_corr  sensor_11_corr  sensor_12_corr
# 0            0.269030        0.329348        0.227136
# 1            0.595769        0.320992        0.454433
# 2            0.577366        0.327406        0.357210
# 3            0.490918        0.358366        0.509921
# 4            0.136277        0.393332        0.280330
# ...               ...             ...             ...
# 25963        0.262241        0.333007        0.259081
# 25964        0.139471        0.296125        0.496935
# 25965        0.234260        0.298284        0.247077
# 25966        0.301672        0.771173        0.296740
# 25967        0.082684        0.362209        0.348291
#
# [25968 rows x 276 columns]

# %% [markdown]
# ### do a brute force xgboost

# %%
X, y = train.drop(columns=['sequence','subject','label']).values, train['label'].values

# %%
X.shape, y.shape
# Out:
# ((25968, 273), (25968,))

# %%
def gridsearch_xgboost(params, X, y, obj="binary:logistic"):
    ''' the params include both the fit and the booster params '''
    
    param_names, param_vals = zip(*list(params.items()))
    id_booster, id_fit = [], []
    for idx, name in enumerate(param_names):
        if (name=='early_stopping_rounds'):
            id_fit.append(idx)
        else:
            id_booster.append(idx)
    
    best_test_score = 0.0
    for val_combination in product(*param_vals):
        param_fit, param_booster = {}, {}
        param_fit['eval_metric'] = 'auc'
        for idx in id_fit:
            param_fit[param_names[idx]] = val_combination[idx]
        for idx in id_booster:
            param_booster[param_names[idx]] = val_combination[idx]
        print(f"param_fit: {param_fit}")
        print(f"param_booster: {param_booster}")
        
        clf = XGBClassifier(**param_booster, objective=obj, use_label_encoder=False)
        result = defaultdict(list)
        for train_idx, test_idx in kf.split(X, y):
            X_train, y_train = X[train_idx], y[train_idx]
            X_test, y_test = X[test_idx], y[test_idx]
            param_fit['eval_set'] = [(X_test, y_test)]            
            clf.fit(X_train, y_train, **param_fit, verbose=True)
            if hasattr(clf, 'best_ntree_limit'):
                result['ntree'].append(clf.best_ntree_limit)
            else:
                result['ntree'].append(clf.n_estimators)            
            result['score'].append(roc_auc_score(y_test, clf.predict_proba(X_test)[:,1]))
            print(f'stop at {result["ntree"][-1]}, score={result["score"][-1]}')
            break

        mean_test_score = np.mean(result['score'])
        print(f"mean_test_score={mean_test_score}")
        if mean_test_score > best_test_score:
            best_test_score = mean_test_score
            best_param_booster = param_booster
            best_param_booster['n_estimators'] = np.int32(np.mean(result['ntree']))
            dum_clf = deepcopy(clf)
    
    return best_param_booster, dum_clf

# %%
params = {'gamma': [0],
          'max_depth': [6],
          'min_child_weight': [0.0],
          'n_estimators': [10000],
          'early_stopping_rounds': [50],
          'learning_rate': [0.4]}

# %%
best_param_booster, dum_clf = gridsearch_xgboost(params, X, y)
# Out:
# param_fit: {'eval_metric': 'auc', 'early_stopping_rounds': 50}
# param_booster: {'gamma': 0, 'max_depth': 6, 'min_child_weight': 0.0, 'n_estimators': 10000, 'learning_rate': 0.4}
# [0]	validation_0-auc:0.80235
# [1]	validation_0-auc:0.83002
# [2]	validation_0-auc:0.84558
# [3]	validation_0-auc:0.85593
# [4]	validation_0-auc:0.86111
# [5]	validation_0-auc:0.86964
# [6]	validation_0-auc:0.87691
# [7]	validation_0-auc:0.88118
# [8]	validation_0-auc:0.88516
# [9]	validation_0-auc:0.88843
# [10]	validation_0-auc:0.89080
# [11]	validation_0-auc:0.89373
# [12]	validation_0-auc:0.89499
# [13]	validation_0-auc:0.89666
# [14]	validation_0-auc:0.89874
# [15]	validation_0-auc:0.90003
# [16]	validation_0-auc:0.90162
# [17]	validation_0-auc:0.90401
# [18]	validation_0-auc:0.90604
# [19]	validation_0-auc:0.90616
# [20]	validation_0-auc:0.90719
# [21]	validation_0-auc:0.90944
# [22]	validation_0-auc:0.91032
# [23]	validation_0-auc:0.91070
# [24]	validation_0-auc:0.91109
# [25]	validation_0-auc:0.91187
# [26]	validation_0-auc:0.91285
# [27]	validation_0-auc:0.91298
# [28]	validation_0-auc:0.91348
# [29]	validation_0-auc:0.91351
# [30]	validation_0-auc:0.91359
# [31]	validation_0-auc:0.91393
# [32]	validation_0-auc:0.91499
# [33]	validation_0-auc:0.91511
# [34]	validation_0-auc:0.91701
# [35]	validation_0-auc:0.91774
# [36]	validation_0-auc:0.91773
# [37]	validation_0-auc:0.91802
# [38]	validation_0-auc:0.91836
# [39]	validation_0-auc:0.91851
# [40]	validation_0-auc:0.91907
# [41]	validation_0-auc:0.91874
# [42]	validation_0-auc:0.91963
# [43]	validation_0-auc:0.92063
# [44]	validation_0-auc:0.92102
# [45]	validation_0-auc:0.92116
# [46]	validation_0-auc:0.92043
# [47]	validation_0-auc:0.92013
# [48]	validation_0-auc:0.92122
# [49]	validation_0-auc:0.92136
# [50]	validation_0-auc:0.92172
# [51]	validation_0-auc:0.92158
# [52]	validation_0-auc:0.92163
# [53]	validation_0-auc:0.92209
# [54]	validation_0-auc:0.92244
# [55]	validation_0-auc:0.92333
# [56]	validation_0-auc:0.92410
# [57]	validation_0-auc:0.92400
# [58]	validation_0-auc:0.92440
# [59]	validation_0-auc:0.92447
# [60]	validation_0-auc:0.92460
# [61]	validation_0-auc:0.92450
# [62]	validation_0-auc:0.92476
# [63]	validation_0-auc:0.92387
# [64]	validation_0-auc:0.92381
# [65]	validation_0-auc:0.92439
# [66]	validation_0-auc:0.92444
# [67]	validation_0-auc:0.92520
# [68]	validation_0-auc:0.92527
# [69]	validation_0-auc:0.92539
# [70]	validation_0-auc:0.92533
# [71]	validation_0-auc:0.92549
# [72]	validation_0-auc:0.92543
# [73]	validation_0-auc:0.92527
# [74]	validation_0-auc:0.92527
# [75]	validation_0-auc:0.92574
# [76]	validation_0-auc:0.92574
# [77]	validation_0-auc:0.92632
# [78]	validation_0-auc:0.92664
# [79]	validation_0-auc:0.92634
# [80]	validation_0-auc:0.92651
# [81]	validation_0-auc:0.92617
# [82]	validation_0-auc:0.92628
# [83]	validation_0-auc:0.92661
# [84]	validation_0-auc:0.92692
# [85]	validation_0-auc:0.92757
# [86]	validation_0-auc:0.92771
# [87]	validation_0-auc:0.92800
# [88]	validation_0-auc:0.92829
# [89]	validation_0-auc:0.92878
# [90]	validation_0-auc:0.92893
# [91]	validation_0-auc:0.92911
# [92]	validation_0-auc:0.92947
# [93]	validation_0-auc:0.92955
# [94]	validation_0-auc:0.92969
# [95]	validation_0-auc:0.92981
# [96]	validation_0-auc:0.93006
# [97]	validation_0-auc:0.93026
# [98]	validation_0-auc:0.93020
# [99]	validation_0-auc:0.93011
# [100]	validation_0-auc:0.93011
# [101]	validation_0-auc:0.93015
# [102]	validation_0-auc:0.93051
# [103]	validation_0-auc:0.93059
# [104]	validation_0-auc:0.93067
# [105]	validation_0-auc:0.93084
# [106]	validation_0-auc:0.93074
# [107]	validation_0-auc:0.93054
# [108]	validation_0-auc:0.93055
# [109]	validation_0-auc:0.93053
# [110]	validation_0-auc:0.93092
# [111]	validation_0-auc:0.93094
# [112]	validation_0-auc:0.93103
# [113]	validation_0-auc:0.93118
# [114]	validation_0-auc:0.93098
# [115]	validation_0-auc:0.93082
# [116]	validation_0-auc:0.93068
# [117]	validation_0-auc:0.93056
# [118]	validation_0-auc:0.93056
# [119]	validation_0-auc:0.93068
# [120]	validation_0-auc:0.93051
# [121]	validation_0-auc:0.93054
# [122]	validation_0-auc:0.93047
# [123]	validation_0-auc:0.93057
# [124]	validation_0-auc:0.93051
# [125]	validation_0-auc:0.93042
# [126]	validation_0-auc:0.93080
# [127]	validation_0-auc:0.93109
# [128]	validation_0-auc:0.93139
# [129]	validation_0-auc:0.93142
# [130]	validation_0-auc:0.93176
# [131]	validation_0-auc:0.93183
# [132]	validation_0-auc:0.93190
# [133]	validation_0-auc:0.93221
# [134]	validation_0-auc:0.93229
# [135]	validation_0-auc:0.93259
# [136]	validation_0-auc:0.93258
# [137]	validation_0-auc:0.93264
# [138]	validation_0-auc:0.93273
# [139]	validation_0-auc:0.93256
# [140]	validation_0-auc:0.93262
# [141]	validation_0-auc:0.93232
# [142]	validation_0-auc:0.93229
# [143]	validation_0-auc:0.93222
# [144]	validation_0-auc:0.93238
# [145]	validation_0-auc:0.93236
# [146]	validation_0-auc:0.93250
# [147]	validation_0-auc:0.93251
# [148]	validation_0-auc:0.93237
# [149]	validation_0-auc:0.93219
# [150]	validation_0-auc:0.93222
# [151]	validation_0-auc:0.93217
# [152]	validation_0-auc:0.93212
# [153]	validation_0-auc:0.93233
# [154]	validation_0-auc:0.93244
# [155]	validation_0-auc:0.93240
# [156]	validation_0-auc:0.93254
# [157]	validation_0-auc:0.93244
# [158]	validation_0-auc:0.93249
# [159]	validation_0-auc:0.93264
# [160]	validation_0-auc:0.93253
# [161]	validation_0-auc:0.93249
# [162]	validation_0-auc:0.93288
# [163]	validation_0-auc:0.93289
# [164]	validation_0-auc:0.93301
# [165]	validation_0-auc:0.93299
# [166]	validation_0-auc:0.93308
# [167]	validation_0-auc:0.93310
# [168]	validation_0-auc:0.93325
# [169]	validation_0-auc:0.93339
# [170]	validation_0-auc:0.93337
# [171]	validation_0-auc:0.93343
# [172]	validation_0-auc:0.93366
# [173]	validation_0-auc:0.93350
# [174]	validation_0-auc:0.93359
# [175]	validation_0-auc:0.93364
# [176]	validation_0-auc:0.93370
# [177]	validation_0-auc:0.93363
# [178]	validation_0-auc:0.93357
# [179]	validation_0-auc:0.93354
# [180]	validation_0-auc:0.93348
# [181]	validation_0-auc:0.93356
# [182]	validation_0-auc:0.93357
# [183]	validation_0-auc:0.93347
# [184]	validation_0-auc:0.93352
# [185]	validation_0-auc:0.93361
# [186]	validation_0-auc:0.93357
# [187]	validation_0-auc:0.93373
# [188]	validation_0-auc:0.93373
# [189]	validation_0-auc:0.93370
# [190]	validation_0-auc:0.93396
# [191]	validation_0-auc:0.93415
# [192]	validation_0-auc:0.93413
# [193]	validation_0-auc:0.93402
# [194]	validation_0-auc:0.93397
# [195]	validation_0-auc:0.93406
# [196]	validation_0-auc:0.93396
# [197]	validation_0-auc:0.93395
# [198]	validation_0-auc:0.93416
# [199]	validation_0-auc:0.93418
# [200]	validation_0-auc:0.93423
# [201]	validation_0-auc:0.93426
# [202]	validation_0-auc:0.93411
# [203]	validation_0-auc:0.93421
# [204]	validation_0-auc:0.93436
# [205]	validation_0-auc:0.93433
# [206]	validation_0-auc:0.93432
# [207]	validation_0-auc:0.93424
# [208]	validation_0-auc:0.93416
# [209]	validation_0-auc:0.93437
# [210]	validation_0-auc:0.93460
# [211]	validation_0-auc:0.93459
# [212]	validation_0-auc:0.93467
# [213]	validation_0-auc:0.93466
# [214]	validation_0-auc:0.93465
# [215]	validation_0-auc:0.93448
# [216]	validation_0-auc:0.93467
# [217]	validation_0-auc:0.93462
# [218]	validation_0-auc:0.93466
# [219]	validation_0-auc:0.93469
# [220]	validation_0-auc:0.93486
# [221]	validation_0-auc:0.93491
# [222]	validation_0-auc:0.93468
# [223]	validation_0-auc:0.93445
# [224]	validation_0-auc:0.93448
# [225]	validation_0-auc:0.93460
# [226]	validation_0-auc:0.93452
# [227]	validation_0-auc:0.93458
# [228]	validation_0-auc:0.93453
# [229]	validation_0-auc:0.93456
# [230]	validation_0-auc:0.93456
# [231]	validation_0-auc:0.93450
# [232]	validation_0-auc:0.93447
# [233]	validation_0-auc:0.93458
# [234]	validation_0-auc:0.93471
# [235]	validation_0-auc:0.93483
# [236]	validation_0-auc:0.93478
# [237]	validation_0-auc:0.93481
# [238]	validation_0-auc:0.93490
# [239]	validation_0-auc:0.93505
# [240]	validation_0-auc:0.93507
# [241]	validation_0-auc:0.93499
# [242]	validation_0-auc:0.93497
# [243]	validation_0-auc:0.93493
# [244]	validation_0-auc:0.93509
# [245]	validation_0-auc:0.93503
# [246]	validation_0-auc:0.93499
# [247]	validation_0-auc:0.93492
# [248]	validation_0-auc:0.93499
# [249]	validation_0-auc:0.93494
# [250]	validation_0-auc:0.93505
# [251]	validation_0-auc:0.93515
# [252]	validation_0-auc:0.93511
# [253]	validation_0-auc:0.93511
# [254]	validation_0-auc:0.93523
# [255]	validation_0-auc:0.93528
# [256]	validation_0-auc:0.93542
# [257]	validation_0-auc:0.93548
# [258]	validation_0-auc:0.93540
# [259]	validation_0-auc:0.93520
# [260]	validation_0-auc:0.93524
# [261]	validation_0-auc:0.93523
# [262]	validation_0-auc:0.93519
# [263]	validation_0-auc:0.93519
# [264]	validation_0-auc:0.93515
# [265]	validation_0-auc:0.93533
# [266]	validation_0-auc:0.93532
# [267]	validation_0-auc:0.93521
# [268]	validation_0-auc:0.93527
# [269]	validation_0-auc:0.93528
# [270]	validation_0-auc:0.93517
# [271]	validation_0-auc:0.93518
# [272]	validation_0-auc:0.93525
# [273]	validation_0-auc:0.93520
# [274]	validation_0-auc:0.93528
# [275]	validation_0-auc:0.93525
# [276]	validation_0-auc:0.93511
# [277]	validation_0-auc:0.93522
# [278]	validation_0-auc:0.93526
# [279]	validation_0-auc:0.93539
# [280]	validation_0-auc:0.93530
# [281]	validation_0-auc:0.93528
# [282]	validation_0-auc:0.93529
# [283]	validation_0-auc:0.93527
# [284]	validation_0-auc:0.93522
# [285]	validation_0-auc:0.93522
# [286]	validation_0-auc:0.93524
# [287]	validation_0-auc:0.93519
# [288]	validation_0-auc:0.93521
# [289]	validation_0-auc:0.93522
# [290]	validation_0-auc:0.93525
# [291]	validation_0-auc:0.93515
# [292]	validation_0-auc:0.93517
# [293]	validation_0-auc:0.93524
# [294]	validation_0-auc:0.93528
# [295]	validation_0-auc:0.93520
# [296]	validation_0-auc:0.93531
# [297]	validation_0-auc:0.93523
# [298]	validation_0-auc:0.93522
# [299]	validation_0-auc:0.93529
# [300]	validation_0-auc:0.93528
# [301]	validation_0-auc:0.93536
# [302]	validation_0-auc:0.93537
# [303]	validation_0-auc:0.93555
# [304]	validation_0-auc:0.93566
# [305]	validation_0-auc:0.93578
# [306]	validation_0-auc:0.93570
# [307]	validation_0-auc:0.93573
# [308]	validation_0-auc:0.93570
# [309]	validation_0-auc:0.93574
# [310]	validation_0-auc:0.93577
# [311]	validation_0-auc:0.93583
# [312]	validation_0-auc:0.93584
# [313]	validation_0-auc:0.93593
# [314]	validation_0-auc:0.93586
# [315]	validation_0-auc:0.93586
# [316]	validation_0-auc:0.93584
# [317]	validation_0-auc:0.93571
# [318]	validation_0-auc:0.93578
# [319]	validation_0-auc:0.93579
# [320]	validation_0-auc:0.93589
# [321]	validation_0-auc:0.93596
# [322]	validation_0-auc:0.93594
# [323]	validation_0-auc:0.93607
# [324]	validation_0-auc:0.93601
# [325]	validation_0-auc:0.93610
# [326]	validation_0-auc:0.93608
# [327]	validation_0-auc:0.93599
# [328]	validation_0-auc:0.93595
# [329]	validation_0-auc:0.93596
# [330]	validation_0-auc:0.93596
# [331]	validation_0-auc:0.93591
# [332]	validation_0-auc:0.93589
# [333]	validation_0-auc:0.93592
# [334]	validation_0-auc:0.93601
# [335]	validation_0-auc:0.93607
# [336]	validation_0-auc:0.93609
# [337]	validation_0-auc:0.93615
# [338]	validation_0-auc:0.93614
# [339]	validation_0-auc:0.93609
# [340]	validation_0-auc:0.93603
# [341]	validation_0-auc:0.93604
# [342]	validation_0-auc:0.93590
# [343]	validation_0-auc:0.93597
# [344]	validation_0-auc:0.93604
# [345]	validation_0-auc:0.93605
# [346]	validation_0-auc:0.93619
# [347]	validation_0-auc:0.93625
# [348]	validation_0-auc:0.93614
# [349]	validation_0-auc:0.93606
# [350]	validation_0-auc:0.93610
# [351]	validation_0-auc:0.93610
# [352]	validation_0-auc:0.93612
# [353]	validation_0-auc:0.93609
# [354]	validation_0-auc:0.93612
# [355]	validation_0-auc:0.93612
# [356]	validation_0-auc:0.93607
# [357]	validation_0-auc:0.93608
# [358]	validation_0-auc:0.93624
# [359]	validation_0-auc:0.93624
# [360]	validation_0-auc:0.93630
# [361]	validation_0-auc:0.93641
# [362]	validation_0-auc:0.93642
# [363]	validation_0-auc:0.93640
# [364]	validation_0-auc:0.93649
# [365]	validation_0-auc:0.93649
# [366]	validation_0-auc:0.93647
# [367]	validation_0-auc:0.93641
# [368]	validation_0-auc:0.93638
# [369]	validation_0-auc:0.93638
# [370]	validation_0-auc:0.93634
# [371]	validation_0-auc:0.93633
# [372]	validation_0-auc:0.93634
# [373]	validation_0-auc:0.93633
# [374]	validation_0-auc:0.93636
# [375]	validation_0-auc:0.93635
# [376]	validation_0-auc:0.93637
# [377]	validation_0-auc:0.93640
# [378]	validation_0-auc:0.93644
# [379]	validation_0-auc:0.93649
# [380]	validation_0-auc:0.93648
# [381]	validation_0-auc:0.93657
# [382]	validation_0-auc:0.93656
# [383]	validation_0-auc:0.93660
# [384]	validation_0-auc:0.93666
# [385]	validation_0-auc:0.93662
# [386]	validation_0-auc:0.93661
# [387]	validation_0-auc:0.93662
# [388]	validation_0-auc:0.93668
# [389]	validation_0-auc:0.93668
# [390]	validation_0-auc:0.93670
# [391]	validation_0-auc:0.93669
# [392]	validation_0-auc:0.93677
# [393]	validation_0-auc:0.93683
# [394]	validation_0-auc:0.93685
# [395]	validation_0-auc:0.93692
# [396]	validation_0-auc:0.93698
# [397]	validation_0-auc:0.93690
# [398]	validation_0-auc:0.93691
# [399]	validation_0-auc:0.93680
# [400]	validation_0-auc:0.93682
# [401]	validation_0-auc:0.93678
# [402]	validation_0-auc:0.93685
# [403]	validation_0-auc:0.93689
# [404]	validation_0-auc:0.93679
# [405]	validation_0-auc:0.93692
# [406]	validation_0-auc:0.93690
# [407]	validation_0-auc:0.93699
# [408]	validation_0-auc:0.93698
# [409]	validation_0-auc:0.93700
# [410]	validation_0-auc:0.93704
# [411]	validation_0-auc:0.93706
# [412]	validation_0-auc:0.93708
# [413]	validation_0-auc:0.93707
# [414]	validation_0-auc:0.93708
# [415]	validation_0-auc:0.93704
# [416]	validation_0-auc:0.93707
# [417]	validation_0-auc:0.93713
# [418]	validation_0-auc:0.93710
# [419]	validation_0-auc:0.93710
# [420]	validation_0-auc:0.93720
# [421]	validation_0-auc:0.93724
# [422]	validation_0-auc:0.93730
# [423]	validation_0-auc:0.93731
# [424]	validation_0-auc:0.93727
# [425]	validation_0-auc:0.93727
# [426]	validation_0-auc:0.93728
# [427]	validation_0-auc:0.93730
# [428]	validation_0-auc:0.93731
# [429]	validation_0-auc:0.93731
# [430]	validation_0-auc:0.93731
# [431]	validation_0-auc:0.93747
# [432]	validation_0-auc:0.93734
# [433]	validation_0-auc:0.93742
# [434]	validation_0-auc:0.93744
# [435]	validation_0-auc:0.93738
# [436]	validation_0-auc:0.93740
# [437]	validation_0-auc:0.93738
# [438]	validation_0-auc:0.93738
# [439]	validation_0-auc:0.93745
# [440]	validation_0-auc:0.93745
# [441]	validation_0-auc:0.93753
# [442]	validation_0-auc:0.93759
# [443]	validation_0-auc:0.93757
# [444]	validation_0-auc:0.93758
# [445]	validation_0-auc:0.93756
# [446]	validation_0-auc:0.93751
# [447]	validation_0-auc:0.93758
# [448]	validation_0-auc:0.93758
# [449]	validation_0-auc:0.93756
# [450]	validation_0-auc:0.93759
# [451]	validation_0-auc:0.93759
# [452]	validation_0-auc:0.93765
# [453]	validation_0-auc:0.93762
# [454]	validation_0-auc:0.93765
# [455]	validation_0-auc:0.93768
# [456]	validation_0-auc:0.93763
# [457]	validation_0-auc:0.93761
# [458]	validation_0-auc:0.93768
# [459]	validation_0-auc:0.93768
# [460]	validation_0-auc:0.93774
# [461]	validation_0-auc:0.93772
# [462]	validation_0-auc:0.93780
# [463]	validation_0-auc:0.93783
# [464]	validation_0-auc:0.93790
# [465]	validation_0-auc:0.93794
# [466]	validation_0-auc:0.93794
# [467]	validation_0-auc:0.93790
# [468]	validation_0-auc:0.93792
# [469]	validation_0-auc:0.93783
# [470]	validation_0-auc:0.93775
# [471]	validation_0-auc:0.93780
# [472]	validation_0-auc:0.93785
# [473]	validation_0-auc:0.93792
# [474]	validation_0-auc:0.93793
# [475]	validation_0-auc:0.93794
# [476]	validation_0-auc:0.93788
# [477]	validation_0-auc:0.93791
# [478]	validation_0-auc:0.93786
# [479]	validation_0-auc:0.93784
# [480]	validation_0-auc:0.93783
# [481]	validation_0-auc:0.93791
# [482]	validation_0-auc:0.93790
# [483]	validation_0-auc:0.93788
# [484]	validation_0-auc:0.93789
# [485]	validation_0-auc:0.93786
# [486]	validation_0-auc:0.93787
# [487]	validation_0-auc:0.93789
# [488]	validation_0-auc:0.93787
# [489]	validation_0-auc:0.93790
# [490]	validation_0-auc:0.93792
# [491]	validation_0-auc:0.93798
# [492]	validation_0-auc:0.93800
# [493]	validation_0-auc:0.93805
# [494]	validation_0-auc:0.93804
# [495]	validation_0-auc:0.93812
# [496]	validation_0-auc:0.93817
# [497]	validation_0-auc:0.93816
# [498]	validation_0-auc:0.93820
# [499]	validation_0-auc:0.93817
# [500]	validation_0-auc:0.93821
# [501]	validation_0-auc:0.93819
# [502]	validation_0-auc:0.93817
# [503]	validation_0-auc:0.93816
# [504]	validation_0-auc:0.93813
# [505]	validation_0-auc:0.93810
# [506]	validation_0-auc:0.93810
# [507]	validation_0-auc:0.93806
# [508]	validation_0-auc:0.93812
# [509]	validation_0-auc:0.93814
# [510]	validation_0-auc:0.93815
# [511]	validation_0-auc:0.93820
# [512]	validation_0-auc:0.93827
# [513]	validation_0-auc:0.93827
# [514]	validation_0-auc:0.93822
# [515]	validation_0-auc:0.93821
# [516]	validation_0-auc:0.93821
# [517]	validation_0-auc:0.93820
# [518]	validation_0-auc:0.93821
# [519]	validation_0-auc:0.93824
# [520]	validation_0-auc:0.93820
# [521]	validation_0-auc:0.93822
# [522]	validation_0-auc:0.93822
# [523]	validation_0-auc:0.93825
# [524]	validation_0-auc:0.93822
# [525]	validation_0-auc:0.93823
# [526]	validation_0-auc:0.93824
# [527]	validation_0-auc:0.93824
# [528]	validation_0-auc:0.93819
# [529]	validation_0-auc:0.93824
# [530]	validation_0-auc:0.93824
# [531]	validation_0-auc:0.93825
# [532]	validation_0-auc:0.93830
# [533]	validation_0-auc:0.93827
# [534]	validation_0-auc:0.93829
# [535]	validation_0-auc:0.93830
# [536]	validation_0-auc:0.93832
# [537]	validation_0-auc:0.93834
# [538]	validation_0-auc:0.93833
# [539]	validation_0-auc:0.93831
# [540]	validation_0-auc:0.93834
# [541]	validation_0-auc:0.93837
# [542]	validation_0-auc:0.93834
# [543]	validation_0-auc:0.93833
# [544]	validation_0-auc:0.93832
# [545]	validation_0-auc:0.93835
# [546]	validation_0-auc:0.93830
# [547]	validation_0-auc:0.93833
# [548]	validation_0-auc:0.93832
# [549]	validation_0-auc:0.93830
# [550]	validation_0-auc:0.93832
# [551]	validation_0-auc:0.93829
# [552]	validation_0-auc:0.93830
# [553]	validation_0-auc:0.93833
# [554]	validation_0-auc:0.93837
# [555]	validation_0-auc:0.93836
# [556]	validation_0-auc:0.93843
# [557]	validation_0-auc:0.93842
# [558]	validation_0-auc:0.93845
# [559]	validation_0-auc:0.93848
# [560]	validation_0-auc:0.93848
# [561]	validation_0-auc:0.93850
# [562]	validation_0-auc:0.93853
# [563]	validation_0-auc:0.93849
# [564]	validation_0-auc:0.93850
# [565]	validation_0-auc:0.93842
# [566]	validation_0-auc:0.93842
# [567]	validation_0-auc:0.93846
# [568]	validation_0-auc:0.93845
# [569]	validation_0-auc:0.93846
# [570]	validation_0-auc:0.93849
# [571]	validation_0-auc:0.93850
# [572]	validation_0-auc:0.93849
# [573]	validation_0-auc:0.93844
# [574]	validation_0-auc:0.93843
# [575]	validation_0-auc:0.93840
# [576]	validation_0-auc:0.93839
# [577]	validation_0-auc:0.93836
# [578]	validation_0-auc:0.93834
# [579]	validation_0-auc:0.93829
# [580]	validation_0-auc:0.93831
# [581]	validation_0-auc:0.93839
# [582]	validation_0-auc:0.93841
# [583]	validation_0-auc:0.93842
# [584]	validation_0-auc:0.93841
# [585]	validation_0-auc:0.93835
# [586]	validation_0-auc:0.93834
# [587]	validation_0-auc:0.93832
# [588]	validation_0-auc:0.93833
# [589]	validation_0-auc:0.93834
# [590]	validation_0-auc:0.93839
# [591]	validation_0-auc:0.93838
# [592]	validation_0-auc:0.93838
# [593]	validation_0-auc:0.93835
# [594]	validation_0-auc:0.93841
# [595]	validation_0-auc:0.93844
# [596]	validation_0-auc:0.93848
# [597]	validation_0-auc:0.93848
# [598]	validation_0-auc:0.93849
# [599]	validation_0-auc:0.93850
# [600]	validation_0-auc:0.93847
# [601]	validation_0-auc:0.93848
# [602]	validation_0-auc:0.93851
# [603]	validation_0-auc:0.93848
# [604]	validation_0-auc:0.93852
# [605]	validation_0-auc:0.93850
# [606]	validation_0-auc:0.93851
# [607]	validation_0-auc:0.93851
# [608]	validation_0-auc:0.93849
# [609]	validation_0-auc:0.93846
# [610]	validation_0-auc:0.93848
# [611]	validation_0-auc:0.93847
# [612]	validation_0-auc:0.93848
# stop at 563, score=0.9385258200926404
# mean_test_score=0.9385258200926404

# %%
shap_values = shap.TreeExplainer(dum_clf).shap_values(shap.sample(X,1000))
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
shap.summary_plot(shap_values, plot_type='bar', \
                  features=train.drop(columns=['sequence','subject','label']).columns, \
                  max_display=100)

# %%
def prep_corr_tmp(df, dfout):
    sensors = df.columns[3:]
    for sensor in ['sensor_04']:
        X = df[sensor].values.reshape(-1,60).copy()
        mean = np.mean(X, axis=1)[:, np.newaxis]
        X = X - mean
        power = np.sum(np.power(X, 2), axis=1)
        power[power==0] = 1
        power = np.sqrt(power)[:,np.newaxis]
        X = X / power
        
        corr = pd.read_csv('template_corr.csv').values.reshape(-1,)
        dfout[sensor+'_corr1'] = corr

# %%
prep_corr_tmp(series, train)

# %%
train
# Out:
#        sequence  subject  sensor_00_mean  sensor_00_std  sensor_00_median  \
# 0             0       47        0.041744       1.431660         -0.148764
# 1             1       66       -0.069294       1.593907         -0.031298
# 2             2       66       -0.001546       1.147526          0.058733
# 3             3      542        0.029869       1.769705         -0.119784
# 4             4      437        0.059132       2.014779          0.005410
# ...         ...      ...             ...            ...               ...
# 25963     25963      558        0.100773       1.547826          0.193586
# 25964     25964      297        0.017182       1.054727          0.051777
# 25965     25965      129       -0.006466       1.227428         -0.039413
# 25966     25966      170       -0.040417       0.885836         -0.051391
# 25967     25967      327       -0.011850       0.729595          0.069938
#
#        sensor_00_mad  sensor_00_min  sensor_00_max  sensor_00_sum  \
# 0           0.829612      -5.634467       7.534003       2.504637
# 1           0.964271      -6.657651       5.870943      -4.157651
# 2           0.855307      -2.797527       3.402628      -0.092736
# 3           1.379164      -3.643740       4.856260       1.792117
# 4           1.495183      -5.331530       5.455951       3.547913
# ...              ...            ...            ...            ...
# 25963       1.166378      -3.738022       3.974498       6.046368
# 25964       0.646433      -5.220247       2.927357       1.030912
# 25965       0.952644      -3.422720       2.818393      -0.387944
# 25966       0.679951      -2.069552       1.710974      -2.425039
# 25967       0.563919      -2.343895       2.016229      -0.710974
#
#        sensor_00_skew  ...  sensor_04_corr  sensor_05_corr  sensor_06_corr  \
# 0            1.488052  ...        0.199336        0.311452        0.305719
# 1           -0.683454  ...        0.334366        0.320698        0.383905
# 2            0.122688  ...        0.637344        0.484730        0.419941
# 3            0.306005  ...        0.261650        0.450173        0.307201
# 4           -0.216130  ...        0.279822        0.267310        0.404221
# ...               ...  ...             ...             ...             ...
# 25963        0.069687  ...        0.243359        0.578738        0.149248
# 25964       -1.690229  ...        0.193162        0.285754        0.286795
# 25965       -0.142272  ...        0.305936        0.327730        0.375871
# 25966       -0.259944  ...        0.358992        0.262400        0.462162
# 25967       -0.180554  ...        0.150442        0.377231        0.339719
#
#        sensor_07_corr  sensor_08_corr  sensor_09_corr  sensor_10_corr  \
# 0            0.198836        0.442239        0.283562        0.269030
# 1            0.538582        0.367945        0.573946        0.595769
# 2            0.320479        0.409183        0.365350        0.577366
# 3            0.517353        0.418139        0.484548        0.490918
# 4            0.257423        0.344855        0.411843        0.136277
# ...               ...             ...             ...             ...
# 25963        0.536950        0.356715        0.237311        0.262241
# 25964        0.350339        0.323952        0.174574        0.139471
# 25965        0.293960        0.450384        0.200095        0.234260
# 25966        0.445991        0.578244        0.244693        0.301672
# 25967        0.403829        0.389365        0.162789        0.082684
#
#        sensor_11_corr  sensor_12_corr  sensor_04_corr1
# 0            0.329348        0.227136         0.166180
# 1            0.320992        0.454433         0.400776
# 2            0.327406        0.357210         0.340781
# 3            0.358366        0.509921         0.178768
# 4            0.393332        0.280330         0.177860
# ...               ...             ...              ...
# 25963        0.333007        0.259081         0.186671
# 25964        0.296125        0.496935         0.269525
# 25965        0.298284        0.247077         0.583790
# 25966        0.771173        0.296740         0.437540
# 25967        0.362209        0.348291         0.165792
#
# [25968 rows x 277 columns]

# %%
best_param_booster, dum_clf = gridsearch_xgboost(params, X, y)
# Out:
# param_fit: {'eval_metric': 'auc', 'early_stopping_rounds': 50}
# param_booster: {'gamma': 0, 'max_depth': 6, 'min_child_weight': 0.0, 'n_estimators': 10000, 'learning_rate': 0.4}
# [0]	validation_0-auc:0.82478
# [1]	validation_0-auc:0.84351
# [2]	validation_0-auc:0.85851
# [3]	validation_0-auc:0.86775
# [4]	validation_0-auc:0.87804
# [5]	validation_0-auc:0.88453
# [6]	validation_0-auc:0.89319
# [7]	validation_0-auc:0.89891
# [8]	validation_0-auc:0.90177
# [9]	validation_0-auc:0.90521
# [10]	validation_0-auc:0.90800
# [11]	validation_0-auc:0.91026
# [12]	validation_0-auc:0.91233
# [13]	validation_0-auc:0.91247
# [14]	validation_0-auc:0.91603
# [15]	validation_0-auc:0.91755
# [16]	validation_0-auc:0.91798
# [17]	validation_0-auc:0.91979
# [18]	validation_0-auc:0.92021
# [19]	validation_0-auc:0.92234
# [20]	validation_0-auc:0.92319
# [21]	validation_0-auc:0.92387
# [22]	validation_0-auc:0.92426
# [23]	validation_0-auc:0.92491
# [24]	validation_0-auc:0.92559
# [25]	validation_0-auc:0.92672
# [26]	validation_0-auc:0.92710
# [27]	validation_0-auc:0.92738
# [28]	validation_0-auc:0.92824
# [29]	validation_0-auc:0.92968
# [30]	validation_0-auc:0.92987
# [31]	validation_0-auc:0.93030
# [32]	validation_0-auc:0.93016
# [33]	validation_0-auc:0.93033
# [34]	validation_0-auc:0.93041
# [35]	validation_0-auc:0.93109
# [36]	validation_0-auc:0.93119
# [37]	validation_0-auc:0.93199
# [38]	validation_0-auc:0.93213
# [39]	validation_0-auc:0.93246
# [40]	validation_0-auc:0.93297
# [41]	validation_0-auc:0.93289
# [42]	validation_0-auc:0.93317
# [43]	validation_0-auc:0.93306
# [44]	validation_0-auc:0.93314
# [45]	validation_0-auc:0.93318
# [46]	validation_0-auc:0.93345
# [47]	validation_0-auc:0.93353
# [48]	validation_0-auc:0.93378
# [49]	validation_0-auc:0.93371
# [50]	validation_0-auc:0.93428
# [51]	validation_0-auc:0.93452
# [52]	validation_0-auc:0.93460
# [53]	validation_0-auc:0.93445
# [54]	validation_0-auc:0.93527
# [55]	validation_0-auc:0.93559
# [56]	validation_0-auc:0.93565
# [57]	validation_0-auc:0.93560
# [58]	validation_0-auc:0.93585
# [59]	validation_0-auc:0.93551
# [60]	validation_0-auc:0.93512
# [61]	validation_0-auc:0.93479
# [62]	validation_0-auc:0.93476
# [63]	validation_0-auc:0.93430
# [64]	validation_0-auc:0.93503
# [65]	validation_0-auc:0.93532
# [66]	validation_0-auc:0.93502
# [67]	validation_0-auc:0.93514
# [68]	validation_0-auc:0.93516
# [69]	validation_0-auc:0.93556
# [70]	validation_0-auc:0.93585
# [71]	validation_0-auc:0.93606
# [72]	validation_0-auc:0.93657
# [73]	validation_0-auc:0.93673
# [74]	validation_0-auc:0.93670
# [75]	validation_0-auc:0.93683
# [76]	validation_0-auc:0.93706
# [77]	validation_0-auc:0.93709
# [78]	validation_0-auc:0.93715
# [79]	validation_0-auc:0.93721
# [80]	validation_0-auc:0.93701
# [81]	validation_0-auc:0.93716
# [82]	validation_0-auc:0.93714
# [83]	validation_0-auc:0.93727
# [84]	validation_0-auc:0.93744
# [85]	validation_0-auc:0.93771
# [86]	validation_0-auc:0.93790
# [87]	validation_0-auc:0.93812
# [88]	validation_0-auc:0.93842
# [89]	validation_0-auc:0.93854
# [90]	validation_0-auc:0.93878
# [91]	validation_0-auc:0.93886
# [92]	validation_0-auc:0.93878
# [93]	validation_0-auc:0.93885
# [94]	validation_0-auc:0.93897
# [95]	validation_0-auc:0.93895
# [96]	validation_0-auc:0.93888
# [97]	validation_0-auc:0.93891
# [98]	validation_0-auc:0.93896
# [99]	validation_0-auc:0.93900
# [100]	validation_0-auc:0.93878
# [101]	validation_0-auc:0.93885
# [102]	validation_0-auc:0.93897
# [103]	validation_0-auc:0.93944
# [104]	validation_0-auc:0.93947
# [105]	validation_0-auc:0.93938
# [106]	validation_0-auc:0.93921
# [107]	validation_0-auc:0.93929
# [108]	validation_0-auc:0.93926
# [109]	validation_0-auc:0.93940
# [110]	validation_0-auc:0.93955
# [111]	validation_0-auc:0.93953
# [112]	validation_0-auc:0.93951
# [113]	validation_0-auc:0.93942
# [114]	validation_0-auc:0.93922
# [115]	validation_0-auc:0.93905
# [116]	validation_0-auc:0.93931
# [117]	validation_0-auc:0.93935
# [118]	validation_0-auc:0.93948
# [119]	validation_0-auc:0.93950
# [120]	validation_0-auc:0.93967
# [121]	validation_0-auc:0.93969
# [122]	validation_0-auc:0.93969
# [123]	validation_0-auc:0.93956
# [124]	validation_0-auc:0.93971
# [125]	validation_0-auc:0.93945
# [126]	validation_0-auc:0.93968
# [127]	validation_0-auc:0.93976
# [128]	validation_0-auc:0.93968
# [129]	validation_0-auc:0.93986
# [130]	validation_0-auc:0.93976
# [131]	validation_0-auc:0.94007
# [132]	validation_0-auc:0.94048
# [133]	validation_0-auc:0.94037
# [134]	validation_0-auc:0.94049
# [135]	validation_0-auc:0.94073
# [136]	validation_0-auc:0.94075
# [137]	validation_0-auc:0.94083
# [138]	validation_0-auc:0.94094
# [139]	validation_0-auc:0.94058
# [140]	validation_0-auc:0.94066
# [141]	validation_0-auc:0.94084
# [142]	validation_0-auc:0.94080
# [143]	validation_0-auc:0.94077
# [144]	validation_0-auc:0.94077
# [145]	validation_0-auc:0.94072
# [146]	validation_0-auc:0.94066
# [147]	validation_0-auc:0.94062
# [148]	validation_0-auc:0.94063
# [149]	validation_0-auc:0.94068
# [150]	validation_0-auc:0.94066
# [151]	validation_0-auc:0.94065
# [152]	validation_0-auc:0.94079
# [153]	validation_0-auc:0.94075
# [154]	validation_0-auc:0.94083
# [155]	validation_0-auc:0.94075
# [156]	validation_0-auc:0.94097
# [157]	validation_0-auc:0.94086
# [158]	validation_0-auc:0.94108
# [159]	validation_0-auc:0.94127
# [160]	validation_0-auc:0.94124
# [161]	validation_0-auc:0.94130
# [162]	validation_0-auc:0.94157
# [163]	validation_0-auc:0.94166
# [164]	validation_0-auc:0.94147
# [165]	validation_0-auc:0.94178
# [166]	validation_0-auc:0.94169
# [167]	validation_0-auc:0.94176
# [168]	validation_0-auc:0.94179
# [169]	validation_0-auc:0.94178
# [170]	validation_0-auc:0.94171
# [171]	validation_0-auc:0.94163
# [172]	validation_0-auc:0.94182
# [173]	validation_0-auc:0.94198
# [174]	validation_0-auc:0.94210
# [175]	validation_0-auc:0.94208
# [176]	validation_0-auc:0.94234
# [177]	validation_0-auc:0.94231
# [178]	validation_0-auc:0.94248
# [179]	validation_0-auc:0.94259
# [180]	validation_0-auc:0.94252
# [181]	validation_0-auc:0.94276
# [182]	validation_0-auc:0.94268
# [183]	validation_0-auc:0.94283
# [184]	validation_0-auc:0.94281
# [185]	validation_0-auc:0.94270
# [186]	validation_0-auc:0.94255
# [187]	validation_0-auc:0.94260
# [188]	validation_0-auc:0.94259
# [189]	validation_0-auc:0.94266
# [190]	validation_0-auc:0.94272
# [191]	validation_0-auc:0.94244
# [192]	validation_0-auc:0.94254
# [193]	validation_0-auc:0.94259
# [194]	validation_0-auc:0.94270
# [195]	validation_0-auc:0.94274
# [196]	validation_0-auc:0.94274
# [197]	validation_0-auc:0.94271
# [198]	validation_0-auc:0.94283
# [199]	validation_0-auc:0.94290
# [200]	validation_0-auc:0.94280
# [201]	validation_0-auc:0.94290
# [202]	validation_0-auc:0.94294
# [203]	validation_0-auc:0.94305
# [204]	validation_0-auc:0.94296
# [205]	validation_0-auc:0.94289
# [206]	validation_0-auc:0.94288
# [207]	validation_0-auc:0.94276
# [208]	validation_0-auc:0.94274
# [209]	validation_0-auc:0.94291
# [210]	validation_0-auc:0.94308
# [211]	validation_0-auc:0.94307
# [212]	validation_0-auc:0.94311
# [213]	validation_0-auc:0.94316
# [214]	validation_0-auc:0.94328
# [215]	validation_0-auc:0.94319
# [216]	validation_0-auc:0.94334
# [217]	validation_0-auc:0.94351
# [218]	validation_0-auc:0.94338
# [219]	validation_0-auc:0.94345
# [220]	validation_0-auc:0.94340
# [221]	validation_0-auc:0.94353
# [222]	validation_0-auc:0.94351
# [223]	validation_0-auc:0.94349
# [224]	validation_0-auc:0.94362
# [225]	validation_0-auc:0.94363
# [226]	validation_0-auc:0.94382
# [227]	validation_0-auc:0.94409
# [228]	validation_0-auc:0.94397
# [229]	validation_0-auc:0.94419
# [230]	validation_0-auc:0.94425
# [231]	validation_0-auc:0.94437
# [232]	validation_0-auc:0.94437
# [233]	validation_0-auc:0.94436
# [234]	validation_0-auc:0.94435
# [235]	validation_0-auc:0.94424
# [236]	validation_0-auc:0.94424
# [237]	validation_0-auc:0.94425
# [238]	validation_0-auc:0.94441
# [239]	validation_0-auc:0.94450
# [240]	validation_0-auc:0.94465
# [241]	validation_0-auc:0.94456
# [242]	validation_0-auc:0.94464
# [243]	validation_0-auc:0.94498
# [244]	validation_0-auc:0.94487
# [245]	validation_0-auc:0.94493
# [246]	validation_0-auc:0.94487
# [247]	validation_0-auc:0.94494
# [248]	validation_0-auc:0.94504
# [249]	validation_0-auc:0.94506
# [250]	validation_0-auc:0.94510
# [251]	validation_0-auc:0.94524
# [252]	validation_0-auc:0.94525
# [253]	validation_0-auc:0.94523
# [254]	validation_0-auc:0.94529
# [255]	validation_0-auc:0.94535
# [256]	validation_0-auc:0.94548
# [257]	validation_0-auc:0.94552
# [258]	validation_0-auc:0.94553
# [259]	validation_0-auc:0.94547
# [260]	validation_0-auc:0.94541
# [261]	validation_0-auc:0.94549
# [262]	validation_0-auc:0.94555
# [263]	validation_0-auc:0.94551
# [264]	validation_0-auc:0.94561
# [265]	validation_0-auc:0.94567
# [266]	validation_0-auc:0.94567
# [267]	validation_0-auc:0.94556
# [268]	validation_0-auc:0.94559
# [269]	validation_0-auc:0.94570
# [270]	validation_0-auc:0.94571
# [271]	validation_0-auc:0.94582
# [272]	validation_0-auc:0.94581
# [273]	validation_0-auc:0.94584
# [274]	validation_0-auc:0.94588
# [275]	validation_0-auc:0.94594
# [276]	validation_0-auc:0.94596
# [277]	validation_0-auc:0.94599
# [278]	validation_0-auc:0.94605
# [279]	validation_0-auc:0.94610
# [280]	validation_0-auc:0.94608
# [281]	validation_0-auc:0.94606
# [282]	validation_0-auc:0.94614
# [283]	validation_0-auc:0.94612
# [284]	validation_0-auc:0.94617
# [285]	validation_0-auc:0.94629
# [286]	validation_0-auc:0.94635
# [287]	validation_0-auc:0.94623
# [288]	validation_0-auc:0.94611
# [289]	validation_0-auc:0.94615
# [290]	validation_0-auc:0.94625
# [291]	validation_0-auc:0.94621
# [292]	validation_0-auc:0.94619
# [293]	validation_0-auc:0.94614
# [294]	validation_0-auc:0.94618
# [295]	validation_0-auc:0.94623
# [296]	validation_0-auc:0.94625
# [297]	validation_0-auc:0.94624
# [298]	validation_0-auc:0.94628
# [299]	validation_0-auc:0.94630
# [300]	validation_0-auc:0.94626
# [301]	validation_0-auc:0.94630
# [302]	validation_0-auc:0.94633
# [303]	validation_0-auc:0.94634
# [304]	validation_0-auc:0.94631
# [305]	validation_0-auc:0.94639
# [306]	validation_0-auc:0.94635
# [307]	validation_0-auc:0.94634
# [308]	validation_0-auc:0.94637
# [309]	validation_0-auc:0.94638
# [310]	validation_0-auc:0.94632
# [311]	validation_0-auc:0.94622
# [312]	validation_0-auc:0.94627
# [313]	validation_0-auc:0.94626
# [314]	validation_0-auc:0.94628
# [315]	validation_0-auc:0.94629
# [316]	validation_0-auc:0.94631
# [317]	validation_0-auc:0.94630
# [318]	validation_0-auc:0.94637
# [319]	validation_0-auc:0.94639
# [320]	validation_0-auc:0.94641
# [321]	validation_0-auc:0.94637
# [322]	validation_0-auc:0.94646
# [323]	validation_0-auc:0.94648
# [324]	validation_0-auc:0.94654
# [325]	validation_0-auc:0.94653
# [326]	validation_0-auc:0.94657
# [327]	validation_0-auc:0.94653
# [328]	validation_0-auc:0.94649
# [329]	validation_0-auc:0.94657
# [330]	validation_0-auc:0.94659
# [331]	validation_0-auc:0.94655
# [332]	validation_0-auc:0.94652
# [333]	validation_0-auc:0.94658
# [334]	validation_0-auc:0.94654
# [335]	validation_0-auc:0.94659
# [336]	validation_0-auc:0.94660
# [337]	validation_0-auc:0.94665
# [338]	validation_0-auc:0.94666
# [339]	validation_0-auc:0.94666
# [340]	validation_0-auc:0.94666
# [341]	validation_0-auc:0.94664
# [342]	validation_0-auc:0.94657
# [343]	validation_0-auc:0.94660
# [344]	validation_0-auc:0.94668
# [345]	validation_0-auc:0.94669
# [346]	validation_0-auc:0.94670
# [347]	validation_0-auc:0.94666
# [348]	validation_0-auc:0.94668
# [349]	validation_0-auc:0.94667
# [350]	validation_0-auc:0.94675
# [351]	validation_0-auc:0.94672
# [352]	validation_0-auc:0.94678
# [353]	validation_0-auc:0.94674
# [354]	validation_0-auc:0.94676
# [355]	validation_0-auc:0.94673
# [356]	validation_0-auc:0.94675
# [357]	validation_0-auc:0.94667
# [358]	validation_0-auc:0.94670
# [359]	validation_0-auc:0.94676
# [360]	validation_0-auc:0.94676
# [361]	validation_0-auc:0.94672
# [362]	validation_0-auc:0.94666
# [363]	validation_0-auc:0.94660
# [364]	validation_0-auc:0.94668
# [365]	validation_0-auc:0.94668
# [366]	validation_0-auc:0.94671
# [367]	validation_0-auc:0.94668
# [368]	validation_0-auc:0.94670
# [369]	validation_0-auc:0.94663
# [370]	validation_0-auc:0.94666
# [371]	validation_0-auc:0.94663
# [372]	validation_0-auc:0.94657
# [373]	validation_0-auc:0.94657
# [374]	validation_0-auc:0.94663
# [375]	validation_0-auc:0.94669
# [376]	validation_0-auc:0.94661
# [377]	validation_0-auc:0.94664
# [378]	validation_0-auc:0.94660
# [379]	validation_0-auc:0.94666
# [380]	validation_0-auc:0.94664
# [381]	validation_0-auc:0.94660
# [382]	validation_0-auc:0.94656
# [383]	validation_0-auc:0.94661
# [384]	validation_0-auc:0.94657
# [385]	validation_0-auc:0.94651
# [386]	validation_0-auc:0.94651
# [387]	validation_0-auc:0.94650
# [388]	validation_0-auc:0.94657
# [389]	validation_0-auc:0.94656
# [390]	validation_0-auc:0.94655
# [391]	validation_0-auc:0.94657
# [392]	validation_0-auc:0.94659
# [393]	validation_0-auc:0.94666
# [394]	validation_0-auc:0.94660
# [395]	validation_0-auc:0.94651
# [396]	validation_0-auc:0.94656
# [397]	validation_0-auc:0.94660
# [398]	validation_0-auc:0.94664
# [399]	validation_0-auc:0.94669
# [400]	validation_0-auc:0.94663
# [401]	validation_0-auc:0.94662
# [402]	validation_0-auc:0.94668
# stop at 353, score=0.9467810140621202
# mean_test_score=0.9467810140621202

# %%
shap_values = shap.TreeExplainer(dum_clf).shap_values(X)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
shap.summary_plot(shap_values, plot_type='bar', \
                  features=train.drop(columns=['sequence','subject','label']).columns, \
                  max_display=100)

# %%
w1 = pd.read_csv('template_corr.csv').values
w2 = pd.read_csv('template_corr_sensor_04.csv').values
plt.plot(w1,w2,'.')

# %%
id0, id1 = (labels['state']==0), (labels['state']==1)

# %%
plt.hist(w1[id0],bins=20);
plt.hist(w1[id1],bins=20,alpha=0.5);

# %%
np.median(w1[id0]) - np.median(w1[id1]), np.median(w2[id0]) - np.median(w2[id1])
# Out:
# (-0.09194519283703378, -0.09718503622447594)

# %%
plt.hist(w2[id0],bins=20);
plt.hist(w2[id1],bins=20,alpha=0.5);

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.metrics import accuracy_score

# %%
clf = LogisticRegression()
clf.fit(w1, labels.values[:,0])
accuracy_score(labels.values[:,0], clf.predict(w1))
# Out:
# 0.6243068391866913

# %%
clf = LogisticRegression()
clf.fit(w2, labels.values[:,0])
accuracy_score(labels.values[:,0], clf.predict(w2))
# Out:
# 0.6328558225508318

# %% [markdown]
# ### try again with clf ooutput (template_run2.py)

# %%
train = prep(series)
# Out:
# doing sensor_00
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew', 'sensor_00_quantile_0.1',
#        'sensor_00_quantile_0.9'],
#       dtype='object')
# doing sensor_01
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew', 'sensor_00_quantile_0.1',
#        'sensor_00_quantile_0.9', 'sensor_01_mean', 'sensor_01_std',
#        'sensor_01_median', 'sensor_01_mad', 'sensor_01_min', 'sensor_01_max',
#        'sensor_01_sum', 'sensor_01_skew', 'sensor_01_quantile_0.1',
#        'sensor_01_quantile_0.9'],
#       dtype='object')
# doing sensor_02
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew', 'sensor_00_quantile_0.1',
#        'sensor_00_quantile_0.9', 'sensor_01_mean', 'sensor_01_std',
#        'sensor_01_median', 'sensor_01_mad', 'sensor_01_min', 'sensor_01_max',
#        'sensor_01_sum', 'sensor_01_skew', 'sensor_01_quantile_0.1',
#        'sensor_01_quantile_0.9', 'sensor_02_mean', 'sensor_02_std',
#        'sensor_02_median', 'sensor_02_mad', 'sensor_02_min', 'sensor_02_max',
#        'sensor_02_sum', 'sensor_02_skew', 'sensor_02_quantile_0.1',
#        'sensor_02_quantile_0.9'],
#       dtype='object')
# doing sensor_03
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew', 'sensor_00_quantile_0.1',
#        'sensor_00_quantile_0.9', 'sensor_01_mean', 'sensor_01_std',
#        'sensor_01_median', 'sensor_01_mad', 'sensor_01_min', 'sensor_01_max',
#        'sensor_01_sum', 'sensor_01_skew', 'sensor_01_quantile_0.1',
#        'sensor_01_quantile_0.9', 'sensor_02_mean', 'sensor_02_std',
#        'sensor_02_median', 'sensor_02_mad', 'sensor_02_min', 'sensor_02_max',
#        'sensor_02_sum', 'sensor_02_skew', 'sensor_02_quantile_0.1',
#        'sensor_02_quantile_0.9', 'sensor_03_mean', 'sensor_03_std',
#        'sensor_03_median', 'sensor_03_mad', 'sensor_03_min', 'sensor_03_max',
#        'sensor_03_sum', 'sensor_03_skew', 'sensor_03_quantile_0.1',
#        'sensor_03_quantile_0.9'],
#       dtype='object')
# doing sensor_04
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew', 'sensor_00_quantile_0.1',
#        'sensor_00_quantile_0.9', 'sensor_01_mean', 'sensor_01_std',
#        'sensor_01_median', 'sensor_01_mad', 'sensor_01_min', 'sensor_01_max',
#        'sensor_01_sum', 'sensor_01_skew', 'sensor_01_quantile_0.1',
#        'sensor_01_quantile_0.9', 'sensor_02_mean', 'sensor_02_std',
#        'sensor_02_median', 'sensor_02_mad', 'sensor_02_min', 'sensor_02_max',
#        'sensor_02_sum', 'sensor_02_skew', 'sensor_02_quantile_0.1',
#        'sensor_02_quantile_0.9', 'sensor_03_mean', 'sensor_03_std',
#        'sensor_03_median', 'sensor_03_mad', 'sensor_03_min', 'sensor_03_max',
#        'sensor_03_sum', 'sensor_03_skew', 'sensor_03_quantile_0.1',
#        'sensor_03_quantile_0.9', 'sensor_04_mean', 'sensor_04_std',
#        'sensor_04_median', 'sensor_04_mad', 'sensor_04_min', 'sensor_04_max',
#        'sensor_04_sum', 'sensor_04_skew', 'sensor_04_quantile_0.1',
#        'sensor_04_quantile_0.9'],
#       dtype='object')
# doing sensor_05
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew', 'sensor_00_quantile_0.1',
#        'sensor_00_quantile_0.9', 'sensor_01_mean', 'sensor_01_std',
#        'sensor_01_median', 'sensor_01_mad', 'sensor_01_min', 'sensor_01_max',
#        'sensor_01_sum', 'sensor_01_skew', 'sensor_01_quantile_0.1',
#        'sensor_01_quantile_0.9', 'sensor_02_mean', 'sensor_02_std',
#        'sensor_02_median', 'sensor_02_mad', 'sensor_02_min', 'sensor_02_max',
#        'sensor_02_sum', 'sensor_02_skew', 'sensor_02_quantile_0.1',
#        'sensor_02_quantile_0.9', 'sensor_03_mean', 'sensor_03_std',
#        'sensor_03_median', 'sensor_03_mad', 'sensor_03_min', 'sensor_03_max',
#        'sensor_03_sum', 'sensor_03_skew', 'sensor_03_quantile_0.1',
#        'sensor_03_quantile_0.9', 'sensor_04_mean', 'sensor_04_std',
#        'sensor_04_median', 'sensor_04_mad', 'sensor_04_min', 'sensor_04_max',
#        'sensor_04_sum', 'sensor_04_skew', 'sensor_04_quantile_0.1',
#        'sensor_04_quantile_0.9', 'sensor_05_mean', 'sensor_05_std',
#        'sensor_05_median', 'sensor_05_mad', 'sensor_05_min', 'sensor_05_max',
#        'sensor_05_sum', 'sensor_05_skew', 'sensor_05_quantile_0.1',
#        'sensor_05_quantile_0.9'],
#       dtype='object')
# doing sensor_06
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew', 'sensor_00_quantile_0.1',
#        'sensor_00_quantile_0.9', 'sensor_01_mean', 'sensor_01_std',
#        'sensor_01_median', 'sensor_01_mad', 'sensor_01_min', 'sensor_01_max',
#        'sensor_01_sum', 'sensor_01_skew', 'sensor_01_quantile_0.1',
#        'sensor_01_quantile_0.9', 'sensor_02_mean', 'sensor_02_std',
#        'sensor_02_median', 'sensor_02_mad', 'sensor_02_min', 'sensor_02_max',
#        'sensor_02_sum', 'sensor_02_skew', 'sensor_02_quantile_0.1',
#        'sensor_02_quantile_0.9', 'sensor_03_mean', 'sensor_03_std',
#        'sensor_03_median', 'sensor_03_mad', 'sensor_03_min', 'sensor_03_max',
#        'sensor_03_sum', 'sensor_03_skew', 'sensor_03_quantile_0.1',
#        'sensor_03_quantile_0.9', 'sensor_04_mean', 'sensor_04_std',
#        'sensor_04_median', 'sensor_04_mad', 'sensor_04_min', 'sensor_04_max',
#        'sensor_04_sum', 'sensor_04_skew', 'sensor_04_quantile_0.1',
#        'sensor_04_quantile_0.9', 'sensor_05_mean', 'sensor_05_std',
#        'sensor_05_median', 'sensor_05_mad', 'sensor_05_min', 'sensor_05_max',
#        'sensor_05_sum', 'sensor_05_skew', 'sensor_05_quantile_0.1',
#        'sensor_05_quantile_0.9', 'sensor_06_mean', 'sensor_06_std',
#        'sensor_06_median', 'sensor_06_mad', 'sensor_06_min', 'sensor_06_max',
#        'sensor_06_sum', 'sensor_06_skew', 'sensor_06_quantile_0.1',
#        'sensor_06_quantile_0.9'],
#       dtype='object')
# doing sensor_07
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew', 'sensor_00_quantile_0.1',
#        'sensor_00_quantile_0.9', 'sensor_01_mean', 'sensor_01_std',
#        'sensor_01_median', 'sensor_01_mad', 'sensor_01_min', 'sensor_01_max',
#        'sensor_01_sum', 'sensor_01_skew', 'sensor_01_quantile_0.1',
#        'sensor_01_quantile_0.9', 'sensor_02_mean', 'sensor_02_std',
#        'sensor_02_median', 'sensor_02_mad', 'sensor_02_min', 'sensor_02_max',
#        'sensor_02_sum', 'sensor_02_skew', 'sensor_02_quantile_0.1',
#        'sensor_02_quantile_0.9', 'sensor_03_mean', 'sensor_03_std',
#        'sensor_03_median', 'sensor_03_mad', 'sensor_03_min', 'sensor_03_max',
#        'sensor_03_sum', 'sensor_03_skew', 'sensor_03_quantile_0.1',
#        'sensor_03_quantile_0.9', 'sensor_04_mean', 'sensor_04_std',
#        'sensor_04_median', 'sensor_04_mad', 'sensor_04_min', 'sensor_04_max',
#        'sensor_04_sum', 'sensor_04_skew', 'sensor_04_quantile_0.1',
#        'sensor_04_quantile_0.9', 'sensor_05_mean', 'sensor_05_std',
#        'sensor_05_median', 'sensor_05_mad', 'sensor_05_min', 'sensor_05_max',
#        'sensor_05_sum', 'sensor_05_skew', 'sensor_05_quantile_0.1',
#        'sensor_05_quantile_0.9', 'sensor_06_mean', 'sensor_06_std',
#        'sensor_06_median', 'sensor_06_mad', 'sensor_06_min', 'sensor_06_max',
#        'sensor_06_sum', 'sensor_06_skew', 'sensor_06_quantile_0.1',
#        'sensor_06_quantile_0.9', 'sensor_07_mean', 'sensor_07_std',
#        'sensor_07_median', 'sensor_07_mad', 'sensor_07_min', 'sensor_07_max',
#        'sensor_07_sum', 'sensor_07_skew', 'sensor_07_quantile_0.1',
#        'sensor_07_quantile_0.9'],
#       dtype='object')
# doing sensor_08
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew', 'sensor_00_quantile_0.1',
#        'sensor_00_quantile_0.9', 'sensor_01_mean', 'sensor_01_std',
#        'sensor_01_median', 'sensor_01_mad', 'sensor_01_min', 'sensor_01_max',
#        'sensor_01_sum', 'sensor_01_skew', 'sensor_01_quantile_0.1',
#        'sensor_01_quantile_0.9', 'sensor_02_mean', 'sensor_02_std',
#        'sensor_02_median', 'sensor_02_mad', 'sensor_02_min', 'sensor_02_max',
#        'sensor_02_sum', 'sensor_02_skew', 'sensor_02_quantile_0.1',
#        'sensor_02_quantile_0.9', 'sensor_03_mean', 'sensor_03_std',
#        'sensor_03_median', 'sensor_03_mad', 'sensor_03_min', 'sensor_03_max',
#        'sensor_03_sum', 'sensor_03_skew', 'sensor_03_quantile_0.1',
#        'sensor_03_quantile_0.9', 'sensor_04_mean', 'sensor_04_std',
#        'sensor_04_median', 'sensor_04_mad', 'sensor_04_min', 'sensor_04_max',
#        'sensor_04_sum', 'sensor_04_skew', 'sensor_04_quantile_0.1',
#        'sensor_04_quantile_0.9', 'sensor_05_mean', 'sensor_05_std',
#        'sensor_05_median', 'sensor_05_mad', 'sensor_05_min', 'sensor_05_max',
#        'sensor_05_sum', 'sensor_05_skew', 'sensor_05_quantile_0.1',
#        'sensor_05_quantile_0.9', 'sensor_06_mean', 'sensor_06_std',
#        'sensor_06_median', 'sensor_06_mad', 'sensor_06_min', 'sensor_06_max',
#        'sensor_06_sum', 'sensor_06_skew', 'sensor_06_quantile_0.1',
#        'sensor_06_quantile_0.9', 'sensor_07_mean', 'sensor_07_std',
#        'sensor_07_median', 'sensor_07_mad', 'sensor_07_min', 'sensor_07_max',
#        'sensor_07_sum', 'sensor_07_skew', 'sensor_07_quantile_0.1',
#        'sensor_07_quantile_0.9', 'sensor_08_mean', 'sensor_08_std',
#        'sensor_08_median', 'sensor_08_mad', 'sensor_08_min', 'sensor_08_max',
#        'sensor_08_sum', 'sensor_08_skew', 'sensor_08_quantile_0.1',
#        'sensor_08_quantile_0.9'],
#       dtype='object')
# doing sensor_09
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew',
#        ...
#        'sensor_09_mean', 'sensor_09_std', 'sensor_09_median', 'sensor_09_mad',
#        'sensor_09_min', 'sensor_09_max', 'sensor_09_sum', 'sensor_09_skew',
#        'sensor_09_quantile_0.1', 'sensor_09_quantile_0.9'],
#       dtype='object', length=102)
# doing sensor_10
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew',
#        ...
#        'sensor_10_mean', 'sensor_10_std', 'sensor_10_median', 'sensor_10_mad',
#        'sensor_10_min', 'sensor_10_max', 'sensor_10_sum', 'sensor_10_skew',
#        'sensor_10_quantile_0.1', 'sensor_10_quantile_0.9'],
#       dtype='object', length=112)
# doing sensor_11
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew',
#        ...
#        'sensor_11_mean', 'sensor_11_std', 'sensor_11_median', 'sensor_11_mad',
#        'sensor_11_min', 'sensor_11_max', 'sensor_11_sum', 'sensor_11_skew',
#        'sensor_11_quantile_0.1', 'sensor_11_quantile_0.9'],
#       dtype='object', length=122)
# doing sensor_12
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew',
#        ...
#        'sensor_12_mean', 'sensor_12_std', 'sensor_12_median', 'sensor_12_mad',
#        'sensor_12_min', 'sensor_12_max', 'sensor_12_sum', 'sensor_12_skew',
#        'sensor_12_quantile_0.1', 'sensor_12_quantile_0.9'],
#       dtype='object', length=132)
# doing sensor_00
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew',
#        ...
#        'sensor_00_subject_mean', 'sensor_00_subject_std',
#        'sensor_00_subject_median', 'sensor_00_subject_mad',
#        'sensor_00_subject_min', 'sensor_00_subject_max',
#        'sensor_00_subject_sum', 'sensor_00_subject_skew',
#        'sensor_00_subject_quantile_0.1', 'sensor_00_subject_quantile_0.9'],
#       dtype='object', length=142)
# doing sensor_01
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew',
#        ...
#        'sensor_01_subject_mean', 'sensor_01_subject_std',
#        'sensor_01_subject_median', 'sensor_01_subject_mad',
#        'sensor_01_subject_min', 'sensor_01_subject_max',
#        'sensor_01_subject_sum', 'sensor_01_subject_skew',
#        'sensor_01_subject_quantile_0.1', 'sensor_01_subject_quantile_0.9'],
#       dtype='object', length=152)
# doing sensor_02
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew',
#        ...
#        'sensor_02_subject_mean', 'sensor_02_subject_std',
#        'sensor_02_subject_median', 'sensor_02_subject_mad',
#        'sensor_02_subject_min', 'sensor_02_subject_max',
#        'sensor_02_subject_sum', 'sensor_02_subject_skew',
#        'sensor_02_subject_quantile_0.1', 'sensor_02_subject_quantile_0.9'],
#       dtype='object', length=162)
# doing sensor_03
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew',
#        ...
#        'sensor_03_subject_mean', 'sensor_03_subject_std',
#        'sensor_03_subject_median', 'sensor_03_subject_mad',
#        'sensor_03_subject_min', 'sensor_03_subject_max',
#        'sensor_03_subject_sum', 'sensor_03_subject_skew',
#        'sensor_03_subject_quantile_0.1', 'sensor_03_subject_quantile_0.9'],
#       dtype='object', length=172)
# doing sensor_04
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew',
#        ...
#        'sensor_04_subject_mean', 'sensor_04_subject_std',
#        'sensor_04_subject_median', 'sensor_04_subject_mad',
#        'sensor_04_subject_min', 'sensor_04_subject_max',
#        'sensor_04_subject_sum', 'sensor_04_subject_skew',
#        'sensor_04_subject_quantile_0.1', 'sensor_04_subject_quantile_0.9'],
#       dtype='object', length=182)
# doing sensor_05
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew',
#        ...
#        'sensor_05_subject_mean', 'sensor_05_subject_std',
#        'sensor_05_subject_median', 'sensor_05_subject_mad',
#        'sensor_05_subject_min', 'sensor_05_subject_max',
#        'sensor_05_subject_sum', 'sensor_05_subject_skew',
#        'sensor_05_subject_quantile_0.1', 'sensor_05_subject_quantile_0.9'],
#       dtype='object', length=192)
# doing sensor_06
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew',
#        ...
#        'sensor_06_subject_mean', 'sensor_06_subject_std',
#        'sensor_06_subject_median', 'sensor_06_subject_mad',
#        'sensor_06_subject_min', 'sensor_06_subject_max',
#        'sensor_06_subject_sum', 'sensor_06_subject_skew',
#        'sensor_06_subject_quantile_0.1', 'sensor_06_subject_quantile_0.9'],
#       dtype='object', length=202)
# doing sensor_07
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew',
#        ...
#        'sensor_07_subject_mean', 'sensor_07_subject_std',
#        'sensor_07_subject_median', 'sensor_07_subject_mad',
#        'sensor_07_subject_min', 'sensor_07_subject_max',
#        'sensor_07_subject_sum', 'sensor_07_subject_skew',
#        'sensor_07_subject_quantile_0.1', 'sensor_07_subject_quantile_0.9'],
#       dtype='object', length=212)
# doing sensor_08
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew',
#        ...
#        'sensor_08_subject_mean', 'sensor_08_subject_std',
#        'sensor_08_subject_median', 'sensor_08_subject_mad',
#        'sensor_08_subject_min', 'sensor_08_subject_max',
#        'sensor_08_subject_sum', 'sensor_08_subject_skew',
#        'sensor_08_subject_quantile_0.1', 'sensor_08_subject_quantile_0.9'],
#       dtype='object', length=222)
# doing sensor_09
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew',
#        ...
#        'sensor_09_subject_mean', 'sensor_09_subject_std',
#        'sensor_09_subject_median', 'sensor_09_subject_mad',
#        'sensor_09_subject_min', 'sensor_09_subject_max',
#        'sensor_09_subject_sum', 'sensor_09_subject_skew',
#        'sensor_09_subject_quantile_0.1', 'sensor_09_subject_quantile_0.9'],
#       dtype='object', length=232)
# doing sensor_10
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew',
#        ...
#        'sensor_10_subject_mean', 'sensor_10_subject_std',
#        'sensor_10_subject_median', 'sensor_10_subject_mad',
#        'sensor_10_subject_min', 'sensor_10_subject_max',
#        'sensor_10_subject_sum', 'sensor_10_subject_skew',
#        'sensor_10_subject_quantile_0.1', 'sensor_10_subject_quantile_0.9'],
#       dtype='object', length=242)
# doing sensor_11
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew',
#        ...
#        'sensor_11_subject_mean', 'sensor_11_subject_std',
#        'sensor_11_subject_median', 'sensor_11_subject_mad',
#        'sensor_11_subject_min', 'sensor_11_subject_max',
#        'sensor_11_subject_sum', 'sensor_11_subject_skew',
#        'sensor_11_subject_quantile_0.1', 'sensor_11_subject_quantile_0.9'],
#       dtype='object', length=252)
# doing sensor_12
# Index(['sequence', 'subject', 'sensor_00_mean', 'sensor_00_std',
#        'sensor_00_median', 'sensor_00_mad', 'sensor_00_min', 'sensor_00_max',
#        'sensor_00_sum', 'sensor_00_skew',
#        ...
#        'sensor_12_subject_mean', 'sensor_12_subject_std',
#        'sensor_12_subject_median', 'sensor_12_subject_mad',
#        'sensor_12_subject_min', 'sensor_12_subject_max',
#        'sensor_12_subject_sum', 'sensor_12_subject_skew',
#        'sensor_12_subject_quantile_0.1', 'sensor_12_subject_quantile_0.9'],
#       dtype='object', length=262)

# %%
prep_corr(series, train)

# %%
train
# Out:
#        sequence  subject  sensor_00_mean  sensor_00_std  sensor_00_median  \
# 0             0       47        0.041744       1.431660         -0.148764
# 1             1       66       -0.069294       1.593907         -0.031298
# 2             2       66       -0.001546       1.147526          0.058733
# 3             3      542        0.029869       1.769705         -0.119784
# 4             4      437        0.059132       2.014779          0.005410
# ...         ...      ...             ...            ...               ...
# 25963     25963      558        0.100773       1.547826          0.193586
# 25964     25964      297        0.017182       1.054727          0.051777
# 25965     25965      129       -0.006466       1.227428         -0.039413
# 25966     25966      170       -0.040417       0.885836         -0.051391
# 25967     25967      327       -0.011850       0.729595          0.069938
#
#        sensor_00_mad  sensor_00_min  sensor_00_max  sensor_00_sum  \
# 0           0.829612      -5.634467       7.534003       2.504637
# 1           0.964271      -6.657651       5.870943      -4.157651
# 2           0.855307      -2.797527       3.402628      -0.092736
# 3           1.379164      -3.643740       4.856260       1.792117
# 4           1.495183      -5.331530       5.455951       3.547913
# ...              ...            ...            ...            ...
# 25963       1.166378      -3.738022       3.974498       6.046368
# 25964       0.646433      -5.220247       2.927357       1.030912
# 25965       0.952644      -3.422720       2.818393      -0.387944
# 25966       0.679951      -2.069552       1.710974      -2.425039
# 25967       0.563919      -2.343895       2.016229      -0.710974
#
#        sensor_00_skew  ...  sensor_03_corr  sensor_04_corr  sensor_05_corr  \
# 0            1.488052  ...        0.139691        0.307225        0.294992
# 1           -0.683454  ...        0.361034        0.250046        0.315479
# 2            0.122688  ...        0.167956        0.478490        0.490633
# 3            0.306005  ...        0.250848        0.378907        0.436343
# 4           -0.216130  ...        0.200227        0.490550        0.279390
# ...               ...  ...             ...             ...             ...
# 25963        0.069687  ...        0.205955        0.405664        0.539009
# 25964       -1.690229  ...        0.184173        0.331022        0.205103
# 25965       -0.142272  ...        0.205512        0.306209        0.351176
# 25966       -0.259944  ...        0.262448        0.316495        0.406378
# 25967       -0.180554  ...        0.172890        0.301608        0.435131
#
#        sensor_06_corr  sensor_07_corr  sensor_08_corr  sensor_09_corr  \
# 0            0.159480        0.181459        0.454950        0.200353
# 1            0.250150        0.530328        0.344457        0.323870
# 2            0.112306        0.410492        0.383307        0.235064
# 3            0.157654        0.365340        0.328487        0.467942
# 4            0.284994        0.267245        0.373858        0.363488
# ...               ...             ...             ...             ...
# 25963        0.105567        0.452906        0.417471        0.216181
# 25964        0.176420        0.222221        0.409938        0.159549
# 25965        0.151529        0.238948        0.437131        0.253131
# 25966        0.107083        0.338021        0.679046        0.385791
# 25967        0.095053        0.273078        0.464457        0.204298
#
#        sensor_10_corr  sensor_11_corr  sensor_12_corr
# 0            0.460667        0.260805        0.140798
# 1            0.579536        0.515457        0.458415
# 2            0.501383        0.225241        0.345895
# 3            0.524171        0.356032        0.311603
# 4            0.357679        0.369057        0.480864
# ...               ...             ...             ...
# 25963        0.580516        0.214420        0.431276
# 25964        0.289615        0.189063        0.341505
# 25965        0.245200        0.171515        0.225972
# 25966        0.309241        0.641825        0.363525
# 25967        0.355630        0.248427        0.269471
#
# [25968 rows x 275 columns]

# %%
train['label'] = labels['state']

# %%
train
# Out:
#        sequence  subject  sensor_00_mean  sensor_00_std  sensor_00_median  \
# 0             0       47        0.041744       1.431660         -0.148764
# 1             1       66       -0.069294       1.593907         -0.031298
# 2             2       66       -0.001546       1.147526          0.058733
# 3             3      542        0.029869       1.769705         -0.119784
# 4             4      437        0.059132       2.014779          0.005410
# ...         ...      ...             ...            ...               ...
# 25963     25963      558        0.100773       1.547826          0.193586
# 25964     25964      297        0.017182       1.054727          0.051777
# 25965     25965      129       -0.006466       1.227428         -0.039413
# 25966     25966      170       -0.040417       0.885836         -0.051391
# 25967     25967      327       -0.011850       0.729595          0.069938
#
#        sensor_00_mad  sensor_00_min  sensor_00_max  sensor_00_sum  \
# 0           0.829612      -5.634467       7.534003       2.504637
# 1           0.964271      -6.657651       5.870943      -4.157651
# 2           0.855307      -2.797527       3.402628      -0.092736
# 3           1.379164      -3.643740       4.856260       1.792117
# 4           1.495183      -5.331530       5.455951       3.547913
# ...              ...            ...            ...            ...
# 25963       1.166378      -3.738022       3.974498       6.046368
# 25964       0.646433      -5.220247       2.927357       1.030912
# 25965       0.952644      -3.422720       2.818393      -0.387944
# 25966       0.679951      -2.069552       1.710974      -2.425039
# 25967       0.563919      -2.343895       2.016229      -0.710974
#
#        sensor_00_skew  ...  sensor_04_corr  sensor_05_corr  sensor_06_corr  \
# 0            1.488052  ...        0.307225        0.294992        0.159480
# 1           -0.683454  ...        0.250046        0.315479        0.250150
# 2            0.122688  ...        0.478490        0.490633        0.112306
# 3            0.306005  ...        0.378907        0.436343        0.157654
# 4           -0.216130  ...        0.490550        0.279390        0.284994
# ...               ...  ...             ...             ...             ...
# 25963        0.069687  ...        0.405664        0.539009        0.105567
# 25964       -1.690229  ...        0.331022        0.205103        0.176420
# 25965       -0.142272  ...        0.306209        0.351176        0.151529
# 25966       -0.259944  ...        0.316495        0.406378        0.107083
# 25967       -0.180554  ...        0.301608        0.435131        0.095053
#
#        sensor_07_corr  sensor_08_corr  sensor_09_corr  sensor_10_corr  \
# 0            0.181459        0.454950        0.200353        0.460667
# 1            0.530328        0.344457        0.323870        0.579536
# 2            0.410492        0.383307        0.235064        0.501383
# 3            0.365340        0.328487        0.467942        0.524171
# 4            0.267245        0.373858        0.363488        0.357679
# ...               ...             ...             ...             ...
# 25963        0.452906        0.417471        0.216181        0.580516
# 25964        0.222221        0.409938        0.159549        0.289615
# 25965        0.238948        0.437131        0.253131        0.245200
# 25966        0.338021        0.679046        0.385791        0.309241
# 25967        0.273078        0.464457        0.204298        0.355630
#
#        sensor_11_corr  sensor_12_corr  label
# 0            0.260805        0.140798      0
# 1            0.515457        0.458415      1
# 2            0.225241        0.345895      1
# 3            0.356032        0.311603      1
# 4            0.369057        0.480864      1
# ...               ...             ...    ...
# 25963        0.214420        0.431276      1
# 25964        0.189063        0.341505      0
# 25965        0.171515        0.225972      1
# 25966        0.641825        0.363525      1
# 25967        0.248427        0.269471      0
#
# [25968 rows x 276 columns]

# %%
def gridsearch_xgboost(params, X, y, obj="binary:logistic"):
    ''' the params include both the fit and the booster params '''
    
    param_names, param_vals = zip(*list(params.items()))
    id_booster, id_fit = [], []
    for idx, name in enumerate(param_names):
        if (name=='early_stopping_rounds'):
            id_fit.append(idx)
        else:
            id_booster.append(idx)
    
    best_test_score = 0.0
    for val_combination in product(*param_vals):
        param_fit, param_booster = {}, {}
        param_fit['eval_metric'] = 'auc'
        for idx in id_fit:
            param_fit[param_names[idx]] = val_combination[idx]
        for idx in id_booster:
            param_booster[param_names[idx]] = val_combination[idx]
        print(f"param_fit: {param_fit}")
        print(f"param_booster: {param_booster}")
        
        clf = XGBClassifier(**param_booster, objective=obj, use_label_encoder=False)
        result = defaultdict(list)
        for train_idx, test_idx in kf.split(X, y):
            X_train, y_train = X[train_idx], y[train_idx]
            X_test, y_test = X[test_idx], y[test_idx]
            param_fit['eval_set'] = [(X_test, y_test)]            
            clf.fit(X_train, y_train, **param_fit, verbose=True)
            if hasattr(clf, 'best_ntree_limit'):
                result['ntree'].append(clf.best_ntree_limit)
            else:
                result['ntree'].append(clf.n_estimators)            
            result['score'].append(roc_auc_score(y_test, clf.predict_proba(X_test)[:,1]))
            print(f'stop at {result["ntree"][-1]}, score={result["score"][-1]}')
            break

        mean_test_score = np.mean(result['score'])
        print(f"mean_test_score={mean_test_score}")
        if mean_test_score > best_test_score:
            best_test_score = mean_test_score
            best_param_booster = param_booster
            best_param_booster['n_estimators'] = np.int32(np.mean(result['ntree']))
            dum_clf = deepcopy(clf)
    
    return best_param_booster, dum_clf

# %%
params = {'gamma': [0],
          'max_depth': [6],
          'min_child_weight': [0.0],
          'n_estimators': [10000],
          'early_stopping_rounds': [50],
          'learning_rate': [0.3]}

# %%
X, y = train.drop(columns=['sequence','subject','label']).values, train['label'].values

# %%
best_param_booster, dum_clf = gridsearch_xgboost(params, X, y)
# Out:
# param_fit: {'eval_metric': 'auc', 'early_stopping_rounds': 50}
# param_booster: {'gamma': 0, 'max_depth': 6, 'min_child_weight': 0.0, 'n_estimators': 10000, 'learning_rate': 0.3}
# [0]	validation_0-auc:0.83827
# [1]	validation_0-auc:0.85399
# [2]	validation_0-auc:0.86429
# [3]	validation_0-auc:0.87159
# [4]	validation_0-auc:0.87813
# [5]	validation_0-auc:0.88470
# [6]	validation_0-auc:0.88961
# [7]	validation_0-auc:0.89302
# [8]	validation_0-auc:0.89707
# [9]	validation_0-auc:0.90186
# [10]	validation_0-auc:0.90345
# [11]	validation_0-auc:0.90420
# [12]	validation_0-auc:0.90736
# [13]	validation_0-auc:0.91090
# [14]	validation_0-auc:0.91282
# [15]	validation_0-auc:0.91422
# [16]	validation_0-auc:0.91507
# [17]	validation_0-auc:0.91609
# [18]	validation_0-auc:0.91658
# [19]	validation_0-auc:0.91805
# [20]	validation_0-auc:0.91888
# [21]	validation_0-auc:0.92060
# [22]	validation_0-auc:0.92108
# [23]	validation_0-auc:0.92174
# [24]	validation_0-auc:0.92242
# [25]	validation_0-auc:0.92317
# [26]	validation_0-auc:0.92377
# [27]	validation_0-auc:0.92448
# [28]	validation_0-auc:0.92632
# [29]	validation_0-auc:0.92629
# [30]	validation_0-auc:0.92720
# [31]	validation_0-auc:0.92740
# [32]	validation_0-auc:0.92769
# [33]	validation_0-auc:0.92878
# [34]	validation_0-auc:0.92935
# [35]	validation_0-auc:0.92990
# [36]	validation_0-auc:0.93075
# [37]	validation_0-auc:0.93080
# [38]	validation_0-auc:0.93100
# [39]	validation_0-auc:0.93150
# [40]	validation_0-auc:0.93169
# [41]	validation_0-auc:0.93137
# [42]	validation_0-auc:0.93136
# [43]	validation_0-auc:0.93127
# [44]	validation_0-auc:0.93166
# [45]	validation_0-auc:0.93210
# [46]	validation_0-auc:0.93213
# [47]	validation_0-auc:0.93255
# [48]	validation_0-auc:0.93287
# [49]	validation_0-auc:0.93311
# [50]	validation_0-auc:0.93306
# [51]	validation_0-auc:0.93289
# [52]	validation_0-auc:0.93291
# [53]	validation_0-auc:0.93301
# [54]	validation_0-auc:0.93336
# [55]	validation_0-auc:0.93328
# [56]	validation_0-auc:0.93357
# [57]	validation_0-auc:0.93388
# [58]	validation_0-auc:0.93373
# [59]	validation_0-auc:0.93406
# [60]	validation_0-auc:0.93460
# [61]	validation_0-auc:0.93476
# [62]	validation_0-auc:0.93471
# [63]	validation_0-auc:0.93483
# [64]	validation_0-auc:0.93542
# [65]	validation_0-auc:0.93547
# [66]	validation_0-auc:0.93544
# [67]	validation_0-auc:0.93565
# [68]	validation_0-auc:0.93588
# [69]	validation_0-auc:0.93593
# [70]	validation_0-auc:0.93589
# [71]	validation_0-auc:0.93627
# [72]	validation_0-auc:0.93617
# [73]	validation_0-auc:0.93666
# [74]	validation_0-auc:0.93691
# [75]	validation_0-auc:0.93672
# [76]	validation_0-auc:0.93691
# [77]	validation_0-auc:0.93699
# [78]	validation_0-auc:0.93683
# [79]	validation_0-auc:0.93688
# [80]	validation_0-auc:0.93680
# [81]	validation_0-auc:0.93684
# [82]	validation_0-auc:0.93680
# [83]	validation_0-auc:0.93690
# [84]	validation_0-auc:0.93681
# [85]	validation_0-auc:0.93668
# [86]	validation_0-auc:0.93656
# [87]	validation_0-auc:0.93653
# [88]	validation_0-auc:0.93676
# [89]	validation_0-auc:0.93700
# [90]	validation_0-auc:0.93733
# [91]	validation_0-auc:0.93745
# [92]	validation_0-auc:0.93758
# [93]	validation_0-auc:0.93758
# [94]	validation_0-auc:0.93778
# [95]	validation_0-auc:0.93795
# [96]	validation_0-auc:0.93837
# [97]	validation_0-auc:0.93864
# [98]	validation_0-auc:0.93862
# [99]	validation_0-auc:0.93868
# [100]	validation_0-auc:0.93893
# [101]	validation_0-auc:0.93895
# [102]	validation_0-auc:0.93904
# [103]	validation_0-auc:0.93900
# [104]	validation_0-auc:0.93920
# [105]	validation_0-auc:0.93916
# [106]	validation_0-auc:0.93934
# [107]	validation_0-auc:0.93963
# [108]	validation_0-auc:0.93990
# [109]	validation_0-auc:0.93994
# [110]	validation_0-auc:0.94014
# [111]	validation_0-auc:0.93995
# [112]	validation_0-auc:0.93968
# [113]	validation_0-auc:0.94003
# [114]	validation_0-auc:0.94016
# [115]	validation_0-auc:0.94002
# [116]	validation_0-auc:0.94006
# [117]	validation_0-auc:0.94008
# [118]	validation_0-auc:0.94010
# [119]	validation_0-auc:0.94027
# [120]	validation_0-auc:0.94010
# [121]	validation_0-auc:0.94027
# [122]	validation_0-auc:0.94044
# [123]	validation_0-auc:0.94032
# [124]	validation_0-auc:0.94034
# [125]	validation_0-auc:0.94049
# [126]	validation_0-auc:0.94040
# [127]	validation_0-auc:0.94038
# [128]	validation_0-auc:0.94022
# [129]	validation_0-auc:0.94040
# [130]	validation_0-auc:0.94050
# [131]	validation_0-auc:0.94082
# [132]	validation_0-auc:0.94081
# [133]	validation_0-auc:0.94073
# [134]	validation_0-auc:0.94082
# [135]	validation_0-auc:0.94076
# [136]	validation_0-auc:0.94101
# [137]	validation_0-auc:0.94112
# [138]	validation_0-auc:0.94136
# [139]	validation_0-auc:0.94123
# [140]	validation_0-auc:0.94141
# [141]	validation_0-auc:0.94161
# [142]	validation_0-auc:0.94144
# [143]	validation_0-auc:0.94128
# [144]	validation_0-auc:0.94152
# [145]	validation_0-auc:0.94138
# [146]	validation_0-auc:0.94136
# [147]	validation_0-auc:0.94124
# [148]	validation_0-auc:0.94144
# [149]	validation_0-auc:0.94136
# [150]	validation_0-auc:0.94154
# [151]	validation_0-auc:0.94158
# [152]	validation_0-auc:0.94159
# [153]	validation_0-auc:0.94149
# [154]	validation_0-auc:0.94154
# [155]	validation_0-auc:0.94160
# [156]	validation_0-auc:0.94173
# [157]	validation_0-auc:0.94187
# [158]	validation_0-auc:0.94201
# [159]	validation_0-auc:0.94190
# [160]	validation_0-auc:0.94198
# [161]	validation_0-auc:0.94202
# [162]	validation_0-auc:0.94205
# [163]	validation_0-auc:0.94217
# [164]	validation_0-auc:0.94232
# [165]	validation_0-auc:0.94237
# [166]	validation_0-auc:0.94246
# [167]	validation_0-auc:0.94245
# [168]	validation_0-auc:0.94261
# [169]	validation_0-auc:0.94278
# [170]	validation_0-auc:0.94297
# [171]	validation_0-auc:0.94302
# [172]	validation_0-auc:0.94296
# [173]	validation_0-auc:0.94315
# [174]	validation_0-auc:0.94325
# [175]	validation_0-auc:0.94330
# [176]	validation_0-auc:0.94334
# [177]	validation_0-auc:0.94333
# [178]	validation_0-auc:0.94314
# [179]	validation_0-auc:0.94315
# [180]	validation_0-auc:0.94304
# [181]	validation_0-auc:0.94328
# [182]	validation_0-auc:0.94342
# [183]	validation_0-auc:0.94344
# [184]	validation_0-auc:0.94334
# [185]	validation_0-auc:0.94339
# [186]	validation_0-auc:0.94345
# [187]	validation_0-auc:0.94364
# [188]	validation_0-auc:0.94393
# [189]	validation_0-auc:0.94390
# [190]	validation_0-auc:0.94368
# [191]	validation_0-auc:0.94372
# [192]	validation_0-auc:0.94389
# [193]	validation_0-auc:0.94380
# [194]	validation_0-auc:0.94378
# [195]	validation_0-auc:0.94376
# [196]	validation_0-auc:0.94377
# [197]	validation_0-auc:0.94384
# [198]	validation_0-auc:0.94381
# [199]	validation_0-auc:0.94356
# [200]	validation_0-auc:0.94368
# [201]	validation_0-auc:0.94346
# [202]	validation_0-auc:0.94363
# [203]	validation_0-auc:0.94362
# [204]	validation_0-auc:0.94361
# [205]	validation_0-auc:0.94371
# [206]	validation_0-auc:0.94366
# [207]	validation_0-auc:0.94382
# [208]	validation_0-auc:0.94402
# [209]	validation_0-auc:0.94405
# [210]	validation_0-auc:0.94427
# [211]	validation_0-auc:0.94444
# [212]	validation_0-auc:0.94446
# [213]	validation_0-auc:0.94458
# [214]	validation_0-auc:0.94457
# [215]	validation_0-auc:0.94467
# [216]	validation_0-auc:0.94458
# [217]	validation_0-auc:0.94450
# [218]	validation_0-auc:0.94452
# [219]	validation_0-auc:0.94448
# [220]	validation_0-auc:0.94443
# [221]	validation_0-auc:0.94438
# [222]	validation_0-auc:0.94449
# [223]	validation_0-auc:0.94449
# [224]	validation_0-auc:0.94429
# [225]	validation_0-auc:0.94427
# [226]	validation_0-auc:0.94430
# [227]	validation_0-auc:0.94440
# [228]	validation_0-auc:0.94440
# [229]	validation_0-auc:0.94455
# [230]	validation_0-auc:0.94458
# [231]	validation_0-auc:0.94471
# [232]	validation_0-auc:0.94489
# [233]	validation_0-auc:0.94495
# [234]	validation_0-auc:0.94488
# [235]	validation_0-auc:0.94480
# [236]	validation_0-auc:0.94491
# [237]	validation_0-auc:0.94496
# [238]	validation_0-auc:0.94480
# [239]	validation_0-auc:0.94487
# [240]	validation_0-auc:0.94492
# [241]	validation_0-auc:0.94498
# [242]	validation_0-auc:0.94507
# [243]	validation_0-auc:0.94516
# [244]	validation_0-auc:0.94514
# [245]	validation_0-auc:0.94513
# [246]	validation_0-auc:0.94515
# [247]	validation_0-auc:0.94504
# [248]	validation_0-auc:0.94513
# [249]	validation_0-auc:0.94491
# [250]	validation_0-auc:0.94503
# [251]	validation_0-auc:0.94496
# [252]	validation_0-auc:0.94503
# [253]	validation_0-auc:0.94505
# [254]	validation_0-auc:0.94492
# [255]	validation_0-auc:0.94511
# [256]	validation_0-auc:0.94507
# [257]	validation_0-auc:0.94504
# [258]	validation_0-auc:0.94489
# [259]	validation_0-auc:0.94493
# [260]	validation_0-auc:0.94495
# [261]	validation_0-auc:0.94508
# [262]	validation_0-auc:0.94500
# [263]	validation_0-auc:0.94491
# [264]	validation_0-auc:0.94501
# [265]	validation_0-auc:0.94501
# [266]	validation_0-auc:0.94496
# [267]	validation_0-auc:0.94505
# [268]	validation_0-auc:0.94500
# [269]	validation_0-auc:0.94494
# [270]	validation_0-auc:0.94508
# [271]	validation_0-auc:0.94504
# [272]	validation_0-auc:0.94499
# [273]	validation_0-auc:0.94507
# [274]	validation_0-auc:0.94504
# [275]	validation_0-auc:0.94508
# [276]	validation_0-auc:0.94512
# [277]	validation_0-auc:0.94500
# [278]	validation_0-auc:0.94496
# [279]	validation_0-auc:0.94499
# [280]	validation_0-auc:0.94500
# [281]	validation_0-auc:0.94500
# [282]	validation_0-auc:0.94509
# [283]	validation_0-auc:0.94504
# [284]	validation_0-auc:0.94503
# [285]	validation_0-auc:0.94508
# [286]	validation_0-auc:0.94512
# [287]	validation_0-auc:0.94517
# [288]	validation_0-auc:0.94510
# [289]	validation_0-auc:0.94513
# [290]	validation_0-auc:0.94514
# [291]	validation_0-auc:0.94511
# [292]	validation_0-auc:0.94509
# [293]	validation_0-auc:0.94504
# [294]	validation_0-auc:0.94514
# [295]	validation_0-auc:0.94523
# [296]	validation_0-auc:0.94525
# [297]	validation_0-auc:0.94532
# [298]	validation_0-auc:0.94544
# [299]	validation_0-auc:0.94555
# [300]	validation_0-auc:0.94563
# [301]	validation_0-auc:0.94563
# [302]	validation_0-auc:0.94563
# [303]	validation_0-auc:0.94564
# [304]	validation_0-auc:0.94560
# [305]	validation_0-auc:0.94557
# [306]	validation_0-auc:0.94556
# [307]	validation_0-auc:0.94559
# [308]	validation_0-auc:0.94564
# [309]	validation_0-auc:0.94556
# [310]	validation_0-auc:0.94551
# [311]	validation_0-auc:0.94553
# [312]	validation_0-auc:0.94564
# [313]	validation_0-auc:0.94563
# [314]	validation_0-auc:0.94564
# [315]	validation_0-auc:0.94563
# [316]	validation_0-auc:0.94557
# [317]	validation_0-auc:0.94561
# [318]	validation_0-auc:0.94562
# [319]	validation_0-auc:0.94570
# [320]	validation_0-auc:0.94554
# [321]	validation_0-auc:0.94552
# [322]	validation_0-auc:0.94557
# [323]	validation_0-auc:0.94565
# [324]	validation_0-auc:0.94572
# [325]	validation_0-auc:0.94570
# [326]	validation_0-auc:0.94577
# [327]	validation_0-auc:0.94572
# [328]	validation_0-auc:0.94583
# [329]	validation_0-auc:0.94579
# [330]	validation_0-auc:0.94581
# [331]	validation_0-auc:0.94583
# [332]	validation_0-auc:0.94577
# [333]	validation_0-auc:0.94585
# [334]	validation_0-auc:0.94582
# [335]	validation_0-auc:0.94590
# [336]	validation_0-auc:0.94593
# [337]	validation_0-auc:0.94594
# [338]	validation_0-auc:0.94592
# [339]	validation_0-auc:0.94582
# [340]	validation_0-auc:0.94587
# [341]	validation_0-auc:0.94598
# [342]	validation_0-auc:0.94602
# [343]	validation_0-auc:0.94609
# [344]	validation_0-auc:0.94617
# [345]	validation_0-auc:0.94632
# [346]	validation_0-auc:0.94626
# [347]	validation_0-auc:0.94643
# [348]	validation_0-auc:0.94635
# [349]	validation_0-auc:0.94629
# [350]	validation_0-auc:0.94634
# [351]	validation_0-auc:0.94624
# [352]	validation_0-auc:0.94627
# [353]	validation_0-auc:0.94617
# [354]	validation_0-auc:0.94602
# [355]	validation_0-auc:0.94598
# [356]	validation_0-auc:0.94591
# [357]	validation_0-auc:0.94602
# [358]	validation_0-auc:0.94613
# [359]	validation_0-auc:0.94615
# [360]	validation_0-auc:0.94617
# [361]	validation_0-auc:0.94622
# [362]	validation_0-auc:0.94619
# [363]	validation_0-auc:0.94625
# [364]	validation_0-auc:0.94625
# [365]	validation_0-auc:0.94622
# [366]	validation_0-auc:0.94627
# [367]	validation_0-auc:0.94628
# [368]	validation_0-auc:0.94620
# [369]	validation_0-auc:0.94619
# [370]	validation_0-auc:0.94626
# [371]	validation_0-auc:0.94619
# [372]	validation_0-auc:0.94623
# [373]	validation_0-auc:0.94624
# [374]	validation_0-auc:0.94621
# [375]	validation_0-auc:0.94622
# [376]	validation_0-auc:0.94621
# [377]	validation_0-auc:0.94622
# [378]	validation_0-auc:0.94617
# [379]	validation_0-auc:0.94608
# [380]	validation_0-auc:0.94603
# [381]	validation_0-auc:0.94605
# [382]	validation_0-auc:0.94610
# [383]	validation_0-auc:0.94617
# [384]	validation_0-auc:0.94627
# [385]	validation_0-auc:0.94633
# [386]	validation_0-auc:0.94637
# [387]	validation_0-auc:0.94641
# [388]	validation_0-auc:0.94634
# [389]	validation_0-auc:0.94638
# [390]	validation_0-auc:0.94637
# [391]	validation_0-auc:0.94635
# [392]	validation_0-auc:0.94630
# [393]	validation_0-auc:0.94636
# [394]	validation_0-auc:0.94639
# [395]	validation_0-auc:0.94634
# [396]	validation_0-auc:0.94636
# stop at 348, score=0.9464260508039308
# mean_test_score=0.9464260508039308

# %%
shap_values = shap.TreeExplainer(dum_clf).shap_values(shap.sample(X,2000))
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.

# %%
shap.summary_plot(shap_values, plot_type='bar', \
                  features=train.drop(columns=['sequence','subject','label']).columns, \
                  max_display=100)
