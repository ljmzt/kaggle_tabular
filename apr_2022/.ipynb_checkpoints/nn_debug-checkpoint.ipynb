# %%
import torch
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split

# %%
def prep_withsubject(df):
    scs = {}
    for col in df.columns[3:]:
        sc = StandardScaler()
        df[col] = sc.fit_transform(df[col].values.reshape(-1,1))
        scs[col] = sc
    
    for sensor in df.columns[3:]:
        df[sensor+'_square'] = np.square(df[sensor])
        df[sensor+'_diff'] = df[sensor].diff()
        df.loc[df['step']==0, sensor+'_diff'] = 0.0
        
        tmp = df.groupby(['subject','step']).agg({sensor:'mean'}).to_dict()[sensor]
        df[sensor+'_subject_mean'] = pd.Series(zip(df['subject'], df['step'])).map(tmp)
        
        tmp = df.groupby(['subject','step']).agg({sensor+'_square':'mean'}).to_dict()[sensor+'_square']
        df[sensor+'_square_subject_mean'] = pd.Series(zip(df['subject'], df['step'])).map(tmp)
        
        tmp = df.groupby(['subject','step']).agg({sensor+'_diff':'mean'}).to_dict()[sensor+'_diff']
        df[sensor+'_diff_subject_mean'] = pd.Series(zip(df['subject'], df['step'])).map(tmp)
    
    for col in df.columns[16:]:
        sc = StandardScaler()
        df[col] = sc.fit_transform(df[col].values.reshape(-1,1))
        scs[col] = sc
    
    return scs

# %%
all_series
# Out:
#          sequence  subject  step  sensor_00  sensor_01  sensor_02  sensor_03  \
# 0               0       47     0  -0.196291   0.112395   1.000000   0.329204
# 1               0       47     1  -0.447450   0.134454   1.000000  -0.658407
# 2               0       47     2   0.326893  -0.694328   1.000000   0.330088
# 3               0       47     3   0.523184   0.751050   1.000000   0.976991
# 4               0       47     4   0.272025   1.074580   1.000000  -0.136283
# ...           ...      ...   ...        ...        ...        ...        ...
# 1558075     25967      327    55  -0.282844  -1.217437  -1.666153   0.586726
# 1558076     25967      327    56   0.130603   0.349790  -1.666153  -0.324779
# 1558077     25967      327    57  -0.579598   0.429622  -1.666153   0.319469
# 1558078     25967      327    58   1.278980   1.711134  -1.522820   0.802655
# 1558079     25967      327    59  -1.136012  -3.702731  -1.332820  -0.766372
#
#          sensor_04  sensor_05  sensor_06  ...  sensor_03  sensor_04  \
# 0        -1.004660  -0.131638  -0.127505  ...  -1.466372  -1.289973
# 1         0.162495   0.340314  -0.209472  ...   0.983186  -0.569053
# 2         0.473678   1.280479  -0.094718  ...   1.016814   0.964157
# 3        -0.563287  -0.720269   0.793260  ...  -0.179646   0.969221
# 4         0.398579   0.044877   0.560109  ...  -0.493805  -1.036124
# ...            ...        ...        ...  ...        ...        ...
# 1558075  -0.930698  -0.451010  -0.651184  ...        NaN        NaN
# 1558076   0.775324  -0.332835   0.099271  ...        NaN        NaN
# 1558077   0.308861   0.282723  -0.512750  ...        NaN        NaN
# 1558078  -0.460541  -0.055348   2.405282  ...        NaN        NaN
# 1558079  -0.430027  -0.091997  -2.512750  ...        NaN        NaN
#
#          sensor_05  sensor_06  sensor_07  sensor_08  sensor_09  sensor_10  \
# 0        -4.207928   2.486339  -2.493893        8.0  -1.123555  -1.673048
# 1         1.845924  -3.887978   1.727481       -2.9   0.395231  -0.882233
# 2         2.454749   0.312386   1.154198       -5.6   1.114162   1.525273
# 3        -1.035153  -0.457195   0.254962       -2.7  -0.588873   0.608761
# 4        -1.126402   2.008197  -0.730534        0.0   0.899566  -1.259615
# ...            ...        ...        ...        ...        ...        ...
# 1558075        NaN        NaN        NaN        NaN        NaN        NaN
# 1558076        NaN        NaN        NaN        NaN        NaN        NaN
# 1558077        NaN        NaN        NaN        NaN        NaN        NaN
# 1558078        NaN        NaN        NaN        NaN        NaN        NaN
# 1558079        NaN        NaN        NaN        NaN        NaN        NaN
#
#          sensor_11  sensor_12
# 0        10.980453   0.419011
# 1        -1.871399  -0.008525
# 2       -11.584362   0.139812
# 3        -4.241770  -0.462916
# 4        -0.472222  -0.121483
# ...            ...        ...
# 1558075        NaN        NaN
# 1558076        NaN        NaN
# 1558077        NaN        NaN
# 1558078        NaN        NaN
# 1558079        NaN        NaN
#
# [1558080 rows x 32 columns]

# %%
all_series.columns
# Out:
# Index(['sequence', 'subject', 'step', 'sensor_00', 'sensor_01', 'sensor_02',
#        'sensor_03', 'sensor_04', 'sensor_05', 'sensor_06', 'sensor_07',
#        'sensor_08', 'sensor_09', 'sensor_10', 'sensor_11', 'sensor_12',
#        'sensor_00_square', 'sensor_00_diff', 'sensor_00_subject_mean',
#        'sensor_00_square_subject_mean', 'sensor_00_diff_subject_mean',
#        'sensor_01_square', 'sensor_01_diff', 'sensor_01_subject_mean',
#        'sensor_01_square_subject_mean', 'sensor_01_diff_subject_mean',
#        'sensor_02_square', 'sensor_02_diff', 'sensor_02_subject_mean',
#        'sensor_02_square_subject_mean', 'sensor_02_diff_subject_mean',
#        'sensor_03_square', 'sensor_03_diff', 'sensor_03_subject_mean',
#        'sensor_03_square_subject_mean', 'sensor_03_diff_subject_mean',
#        'sensor_04_square', 'sensor_04_diff', 'sensor_04_subject_mean',
#        'sensor_04_square_subject_mean', 'sensor_04_diff_subject_mean',
#        'sensor_05_square', 'sensor_05_diff', 'sensor_05_subject_mean',
#        'sensor_05_square_subject_mean', 'sensor_05_diff_subject_mean',
#        'sensor_06_square', 'sensor_06_diff', 'sensor_06_subject_mean',
#        'sensor_06_square_subject_mean', 'sensor_06_diff_subject_mean',
#        'sensor_07_square', 'sensor_07_diff', 'sensor_07_subject_mean',
#        'sensor_07_square_subject_mean', 'sensor_07_diff_subject_mean',
#        'sensor_08_square', 'sensor_08_diff', 'sensor_08_subject_mean',
#        'sensor_08_square_subject_mean', 'sensor_08_diff_subject_mean',
#        'sensor_09_square', 'sensor_09_diff', 'sensor_09_subject_mean',
#        'sensor_09_square_subject_mean', 'sensor_09_diff_subject_mean',
#        'sensor_10_square', 'sensor_10_diff', 'sensor_10_subject_mean',
#        'sensor_10_square_subject_mean', 'sensor_10_diff_subject_mean',
#        'sensor_11_square', 'sensor_11_diff', 'sensor_11_subject_mean',
#        'sensor_11_square_subject_mean', 'sensor_11_diff_subject_mean',
#        'sensor_12_square', 'sensor_12_diff', 'sensor_12_subject_mean',
#        'sensor_12_square_subject_mean', 'sensor_12_diff_subject_mean'],
#       dtype='object')

# %%
    train_series = pd.read_csv('train.csv')
    train_labels = pd.read_csv('train_labels.csv')
    test_series = pd.read_csv('test.csv')
    all_series = pd.concat([train_series, test_series], axis=0)
    scs = prep_withsubject(all_series)
    train_series = all_series.loc[all_series['sequence']<=25967]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/cs2020/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /opt/anaconda3/envs/cs2020/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/anaconda3/envs/cs2020/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sensor_00_square'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [5], in <module>
#       3 test_series = pd.read_csv('test.csv')
#       4 all_series = pd.concat([train_series, test_series], axis=0)
# ----> 5 scs = prep_withsubject(all_series)
#       6 train_series = all_series.loc[all_series['sequence']<=25967]
#
# Input In [2], in prep_withsubject(df)
#      22 for col in df.columns[16:]:
#      23     sc = StandardScaler()
# ---> 24     train_series[col] = sc.fit_transform(train_series[col].values.reshape(-1,1))
#      25     scs[col] = sc
#      27 return scs
#
# File /opt/anaconda3/envs/cs2020/lib/python3.9/site-packages/pandas/core/frame.py:3506, in DataFrame.__getitem__(self, key)
#    3504 if self.columns.nlevels > 1:
#    3505     return self._getitem_multilevel(key)
# -> 3506 indexer = self.columns.get_loc(key)
#    3507 if is_integer(indexer):
#    3508     indexer = [indexer]
#
# File /opt/anaconda3/envs/cs2020/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'sensor_00_square'
